# %%
import pandas as pd
import openpyxl

# %%
data=pd.read_excel("../input/staffmaster2/StaffMaster.xlsx",sheet_name=0)

# %%
data
# Out:
#      S.No.  Employee Code                  Name  \
# 0        0        2000006       Shweta Malhotra
# 1        1        2000017    Raj Kumar Pokharel
# 2        2        2000021  Mohammad Sharif Bhat
# 3        3        2000024       Jigmet Gayltsen
# 4        4        2000025       Tsering Targais
# ..     ...            ...                   ...
# 391    391        2055195      Sailendra Sharma
# 392    392        2055401    Sunil Kumar Katare
# 393    393        2055826          Akula Anusha
# 394    394        2056028         Nikita Hunjan
# 395    395        2056430          Vinod V Pote
#
#                                       Designation Grade     Positin Type  \
# 0      Senior Manager - CEO's Office & Governance     E              NSO
# 1                      Assistant - Administration     I              NSO
# 2         Head - Project Office (Jammu & Kashmir)     D            State
# 3    Assistant - Administration (Jammu & Kashmir)     I            State
# 4         Assistant - Transport (Jammu & Kashmir)     I            State
# ..                                            ...   ...              ...
# 391                   Assistant Manager - Project     G  State - Project
# 392                         Coordinator - Project     H  State - Project
# 393            Assistant - Project (Registations)     I  State - Project
# 394             Manager - Human Resources (North)     F              Hub
# 395     Coordinator - Adminstration & Procurement     H  State - Project
#
#     SLT/ Non- SLT SMT/ Non-SMT Employment Classification - For Gratuity  \
# 0             SLT          SMT                                  Regular
# 1         NON-SLT      Non SMT                                  Regular
# 2         NON-SLT      Non SMT                                  Regular
# 3         NON-SLT      Non SMT                                  Regular
# 4         NON-SLT      Non SMT                                  Regular
# ..            ...          ...                                      ...
# 391       NON-SLT      Non SMT                                  Project
# 392       NON-SLT      Non SMT                    Project with gratuity
# 393       NON-SLT      Non SMT                                  Project
# 394       NON-SLT      Non SMT                                  Regular
# 395       NON-SLT      Non SMT                                  Project
#
#     Employment Classification                              Function  \
# 0                     Regular                          CEO's Office
# 1                     Regular  Human Resources, Admin & Procurement
# 2                     Regular              Programme Implementation
# 3                     Regular              Programme Implementation
# 4                     Regular              Programme Implementation
# ..                        ...                                   ...
# 391                       NaN              Programme Implementation
# 392                       NaN              Programme Implementation
# 393                       NaN              Programme Implementation
# 394                       NaN  Human Resources, Admin & Procurement
# 395                       NaN              Programme Implementation
#
#                              Sub-Function                Constituent  \
# 0                            CEO's Office  CEO's Office & Governance
# 1                     Admin & Procurement                      Admin
# 2                Programme Implementation   Programme Implementation
# 3    Human Resources, Admin & Procurement        Procurement & Admin
# 4    Human Resources, Admin & Procurement        Procurement & Admin
# ..                                    ...                        ...
# 391                Project Implementation                        NaN
# 392                Project Implementation                        NaN
# 393                Project Implementation                        NaN
# 394              Programme Implementation                        NaN
# 395                Project Implementation                        NaN
#
#       HUB/ NSO                          Location  Line Manager Employee Code  \
# 0          NSO  National Support Office, Gurgaon                   2027296.0
# 1          NSO  National Support Office, Gurgaon                   2000647.0
# 2    North Hub                   Jammu & Kashmir                   2000280.0
# 3    North Hub                   Jammu & Kashmir                   2000044.0
# 4    North Hub                   Jammu & Kashmir                   2000044.0
# ..         ...                               ...                         ...
# 391   East Hub                       West Bengal                         NaN
# 392   West Hub                    Madhya Pradesh                         NaN
# 393  South Hub                    Andhra Pradesh                         NaN
# 394  North Hub                             Delhi                         NaN
# 395  South Hub                         Karnataka                         NaN
#
#             Line Manager                  Line Manager Email Matrix Manager  \
# 0        Sudarshan Suchi  sudarshan.suchi@savethechildren.in            NaN
# 1        Arvind Krishnan  arvind.krishnan@savethechildren.in            NaN
# 2    Avinash Kumar Singh        s.avinash@savethechildren.in            NaN
# 3          Altaf Hussain        a.hussain@savethechildren.in            NaN
# 4          Altaf Hussain        a.hussain@savethechildren.in            NaN
# ..                   ...                                 ...            ...
# 391                  NaN                                 NaN            NaN
# 392                  NaN                                 NaN            NaN
# 393                  NaN                                 NaN            NaN
# 394                  NaN                                 NaN            NaN
# 395                  NaN                                 NaN            NaN
#
#      Month of Joining        DOJ Probation Confirmation Date  \
# 0                2008 2008-04-01         Probation Completed
# 1                2008 2008-04-01         Probation Completed
# 2                2008 2008-04-01         Probation Completed
# 3                2008 2008-04-01         Probation Completed
# 4                2008 2008-04-01         Probation Completed
# ..                ...        ...                         ...
# 391              2022 2022-08-02         2022-10-31 00:00:00
# 392              2022 2022-08-04         2022-11-02 00:00:00
# 393              2022 2022-08-05         2022-11-03 00:00:00
# 394              2022 2022-08-16         2022-11-14 00:00:00
# 395              2022 2022-08-17         2022-11-15 00:00:00
#
#     Probation / Confirmed                  DOC  Gender                  DOB  \
# 0               Confirmed                   OE  Female  1977-03-01 00:00:00
# 1               Confirmed                   OE    Male  1981-07-28 00:00:00
# 2               Confirmed                   OE    Male  1972-06-22 00:00:00
# 3               Confirmed                   OE    Male  1968-04-03 00:00:00
# 4               Confirmed                   OE    Male  1966-12-12 00:00:00
# ..                    ...                  ...     ...                  ...
# 391             Probation  2023-04-30 00:00:00    Male  1977-12-07 00:00:00
# 392             Probation  2025-06-30 00:00:00    Male  1977-06-02 00:00:00
# 393             Probation  2022-12-31 00:00:00  Female  1990-06-25 00:00:00
# 394             Probation                   OE  Female  1991-10-01 00:00:00
# 395             Probation  2023-07-31 00:00:00    Male  1976-07-22 00:00:00
#
#     (Month of Birth)                  Age Year of Career Start  \
# 0                Mar   45 years, 6 months  2006-06-01 00:00:00
# 1                Jul   41 years, 1 months  2004-07-01 00:00:00
# 2                Jun   50 years, 2 months  1997-06-01 00:00:00
# 3                Apr   54 years, 5 months  1986-06-01 00:00:00
# 4                Dec   55 years, 9 months  1981-06-01 00:00:00
# ..               ...                  ...                  ...
# 391              Dec   44 years, 9 months                  NaN
# 392              Jun   45 years, 3 months  2003-06-01 00:00:00
# 393              Jun   32 years, 2 months  2019-08-01 00:00:00
# 394              Oct  30 years, 11 months  2015-05-01 00:00:00
# 395              Jul   46 years, 1 months  2002-04-04 00:00:00
#
#        Years in SCBR Total Years of Experience  \
# 0    14 yrs, 5 mnths           16 yrs, 3 mnths
# 1    14 yrs, 5 mnths           18 yrs, 2 mnths
# 2    14 yrs, 5 mnths           25 yrs, 3 mnths
# 3    14 yrs, 5 mnths           36 yrs, 3 mnths
# 4    14 yrs, 5 mnths           41 yrs, 3 mnths
# ..               ...                       ...
# 391   0 yrs, 1 mnths          122 yrs, 8 mnths
# 392   0 yrs, 1 mnths           19 yrs, 3 mnths
# 393   0 yrs, 1 mnths            3 yrs, 1 mnths
# 394   0 yrs, 1 mnths            7 yrs, 4 mnths
# 395   0 yrs, 1 mnths           20 yrs, 5 mnths
#
#                                     Qualification Blood Group  \
# 0                                      BA Honours          B-
# 1                                             SSC          B+
# 2                                             MSW          B+
# 3                                     Primary Edu          A+
# 4                                     Primary Edu          A+
# ..                                            ...         ...
# 391                                           NaN         NaN
# 392  MSW \nSpecialization - Community Development          O+
# 393                                      llb,MBA           B+
# 394          Msc - Value Education $ Spirituality         AB+
# 395                                          Bcom          A+
#
#      Employee Code.1                         Email_Address  \
# 0            2000006         s.malhotra@savethechildren.in
# 1            2000017  rajkumar.pokharel@savethechildren.in
# 2            2000021             s.bhat@savethechildren.in
# 3            2000024         j.gyalston@savethechildren.in
# 4            2000025    tsering.targais@savethechildren.in
# ..               ...                                   ...
# 391          2055195   sailendra.sharma@savethechildren.in
# 392          2055401       sunil.katare@savethechildren.in
# 393          2055826       akula.anusha@savethechildren.in
# 394          2056028      nikita.hunjan@savethechildren.in
# 395          2056430         vinod.pote@savethechildren.in
#
#                   Contact Nos         PAN  UAN No./ PF account no.  \
# 0                  9810290780  AACPT5593R             1.003831e+11
# 1                  9873710747  BCEPP1034Q             1.003175e+11
# 2                  9419178360  AOYPB0079G             1.015339e+11
# 3                  9797798997  ANFPG2806C             1.015339e+11
# 4                  9419243599  AGOPT0206H             1.015339e+11
# ..                        ...         ...                      ...
# 391                       NaN  BRDPS0730G                      NaN
# 392  9755224226, \n8770802203  BMOPK2433A             1.015903e+11
# 393                8686664790  AXKPA3469J             1.011922e+11
# 394                9650901055  ALFPH3486F             1.010641e+11
# 395                8660411090  ATUPP1741L             1.009118e+11
#
#      CTC (09/10)  CTC (10/11)  CTC (11/12)  CTC\n(2012)  CTC\n(2013)  \
# 0       409000.0    613994.89   706094.000     759052.0     827367.0
# 1       112000.0    173108.88   207731.000     270000.0     299700.0
# 2      1168020.0   1249781.40  1362261.726    1392913.0    1434701.0
# 3       245250.0    267322.50   291381.525     313236.0     341428.0
# 4       288900.0    314901.00   352689.120     379141.0     413264.0
# ..           ...          ...          ...          ...          ...
# 391          NaN          NaN          NaN          NaN          NaN
# 392          NaN          NaN          NaN          NaN          NaN
# 393          NaN          NaN          NaN          NaN          NaN
# 394          NaN          NaN          NaN          NaN          NaN
# 395          NaN          NaN          NaN          NaN          NaN
#
#      CTC\n(2014)  CTC\n(2015)  CTC\n(2016)  CTC\n(2017-18)  CTC\n(2018-19)  \
# 0      951472.05    1200000.0   1512000.00     1663200.000       1779624.0
# 1      344655.00     392907.0    440055.84      484061.424        527628.0
# 2     1578171.10    1672861.0   1840147.10     1987358.868       2126474.0
# 3      375570.80     401860.0    442046.00      477409.680        510829.0
# 4      446325.12     477568.0    525324.80      567350.784        607066.0
# ..           ...          ...          ...             ...             ...
# 391          NaN          NaN          NaN             NaN             NaN
# 392          NaN          NaN          NaN             NaN             NaN
# 393          NaN          NaN          NaN             NaN             NaN
# 394          NaN          NaN          NaN             NaN             NaN
# 395          NaN          NaN          NaN             NaN             NaN
#
#      CTC\n(2019-20)  CTC\n(2020-21)  CTC\n(2021-22)  CTC\n(2022-23)  \
# 0         2100000.0       2100000.0       2247000.0         2357103
# 1          580391.0        580391.0        626822.0          660357
# 2         2275327.0       2275327.0       2457353.0         2577763
# 3          561912.0        561912.0        606865.0          639332
# 4          649561.0        649561.0        701526.0          739058
# ..              ...             ...             ...             ...
# 391             NaN             NaN             NaN          900000
# 392             NaN             NaN             NaN          600000
# 393             NaN             NaN             NaN          420000
# 394             NaN             NaN             NaN         1550000
# 395             NaN             NaN             NaN          600000
#
#      Corrections  One time Bonus  Basic      HRA  Special allowance  \
# 0            NaN             NaN  88391  44195.5       39763.163333
# 1            NaN             NaN  24763  12381.5       10039.356667
# 2            NaN             NaN  96666  48333.0       46547.996667
# 3            NaN             NaN  23975  11987.5        9601.833333
# 4            NaN             NaN  27715  13857.5       11673.533333
# ..           ...             ...    ...      ...                ...
# 391          NaN             NaN  33750  16875.0       13308.000000
# 392          NaN             NaN  22500  11250.0        7535.000000
# 393          NaN             NaN  15750   7875.0        5802.000000
# 394          NaN             NaN  58125  29063.0       25191.000000
# 395          NaN             NaN  22500  11250.0        8617.000000
#
#      Sodexo Pass  TPT Allowance  Medical\nReimb.   Gross Salary  \
# 0           2200           1600             1250  177399.663333
# 1              0           1600             1250   50033.856667
# 2              0           1600             1250  194396.996667
# 3              0           1600             1250   48414.333333
# 4              0           1600             1250   56096.033333
# ..           ...            ...              ...            ...
# 391            0           1600             1250   66783.000000
# 392            0           1600             1250   44135.000000
# 393            0           1600             1250   32277.000000
# 394            0           1600             1250  115229.000000
# 395            0           1600             1250   45217.000000
#
#      Movable Assets          LTA  Mediclaim        PF  Gratuity  \
# 0               NaN  4166.666667          0  10606.92      4252
# 1               NaN   833.333333          0   2971.56      1191
# 2               NaN  4166.666667          0  11599.92      4650
# 3               NaN   833.333333          0   2877.00      1153
# 4               NaN   833.333333          0   3325.80      1333
# ..              ...          ...        ...       ...       ...
# 391             NaN  4167.000000          0   4050.00         0
# 392             NaN  2083.000000          0   2700.00      1082
# 393             NaN   833.000000          0   1890.00         0
# 394             NaN  4167.000000          0   6975.00      2796
# 395             NaN  2083.000000          0   2700.00         0
#
#        CTC Monthly  CTC Annual  Check  PMS 07-08  PMS 08-09  PMS 09-10  \
# 0    196425.250000   2357103.0    0.0        5.0        4.0        4.0
# 1     55029.750000    660357.0    0.0        NaN        4.0        4.0
# 2    214813.583333   2577763.0    0.0        2.0        3.0        3.0
# 3     53277.666667    639332.0    0.0        4.0        5.0        4.0
# 4     61588.166667    739058.0    0.0        4.0        4.0        4.0
# ..             ...         ...    ...        ...        ...        ...
# 391   75000.000000    900000.0    0.0        NaN        NaN        NaN
# 392   50000.000000    600000.0    0.0        NaN        NaN        NaN
# 393   35000.000000    420000.0    0.0        NaN        NaN        NaN
# 394  129167.000000   1550004.0    4.0        NaN        NaN        NaN
# 395   50000.000000    600000.0    0.0        NaN        NaN        NaN
#
#      PMS 10-11  PMS 11-12  PMS 12-13  PMS 13-14 PMS 14-15 PMS 15-16 PMS 16-17  \
# 0          5.0        4.0        3.0        4.0         3         3         4
# 1          4.0        3.0        4.0        4.0         4         4         4
# 2          4.0        2.0        2.0        4.0         3         3         3
# 3          4.0        4.0        3.0        4.0         3         3         3
# 4          5.0        4.0        3.0        3.0         3         3         3
# ..         ...        ...        ...        ...       ...       ...       ...
# 391        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 392        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 393        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 394        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 395        NaN        NaN        NaN        NaN       NaN       NaN       NaN
#
#     PMS 17-18 PMS 18-19  PMS 2019-20 PMS 2020-21        Aadhar  \
# 0           3         3          4.0           3           NaN
# 1           4         4          3.0           3           NaN
# 2           3         3          3.0           4           NaN
# 3           3         4          3.0           3           NaN
# 4           3         3          3.0           3           NaN
# ..        ...       ...          ...         ...           ...
# 391       NaN       NaN          NaN         NaN  763267797193
# 392       NaN       NaN          NaN         NaN  575148775801
# 393       NaN       NaN          NaN         NaN  851646725487
# 394       NaN       NaN          NaN         NaN  704574651586
# 395       NaN       NaN          NaN         NaN  668572918871
#
#     Emergency Contact Nos         Father's Name Single / Married  \
# 0            011-40562074                   NaN          Married
# 1              8285512193                   NaN          Married
# 2              9469612000                   NaN          Married
# 3              9797798997                   NaN           Single
# 4              9419243599                   NaN          Married
# ..                    ...                   ...              ...
# 391            7890011949  Late. Gajanan Sharma          Married
# 392            6260632032   Badri Prasad Katare          Married
# 393            9848406542  AKULA SATYANARAYANA        Unmarried
# 394            9810915407          Rakesh Kumar       Unmarried
# 395            9901456226               Vinayak          Married
#
#         Date of Marriage Month of Marriage Current Address  \
# 0    1997-09-14 00:00:00         September             NaN
# 1    2009-05-22 00:00:00               May             NaN
# 2    2006-06-22 00:00:00              June             NaN
# 3                      -                 -             NaN
# 4    1989-10-19 00:00:00           October             NaN
# ..                   ...               ...             ...
# 391  2005-01-30 00:00:00           January             NaN
# 392  2004-04-29 00:00:00             April             NaN
# 393                  NaN               NaN             NaN
# 394                  NaN               NaN             NaN
# 395  2008-11-21 00:00:00          November             NaN
#
#                                                Address Unnamed: 91  \
# 0    92, Mandakini Enclave, Alaknanda, New Delhi - ...         NaN
# 1    262/12, UGF, Amritpuri B, East of Kailash. New...         NaN
# 2    Majied Bagh Custodial colony Sanatnager House ...         NaN
# 3    Korpon Nyoma, Sub Division Nyoma Changthang Le...         NaN
# 4    Near Post office Staff quarter, Housing Colony...         NaN
# ..                                                 ...         ...
# 391     53 Janata Road, New Santoshpur, Kolkata-700075         NaN
# 392  House No. 3158, Ward No. 14, Shastri Colony, N...         NaN
# 393               10-3-217/1 ,saroornagar, Hyderabad .         NaN
# 394                  B-17/254 Bharat Nagar , Ludhiana.         NaN
# 395  House No-2085, Ward no-29, Ramdev Galli, Jamkh...         NaN
#
#     Unnamed: 92 Unnamed: 93
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 391         NaN         NaN
# 392         NaN         NaN
# 393         NaN         NaN
# 394         NaN         NaN
# 395         NaN         NaN
#
# [396 rows x 94 columns]

# %%
data.columns
# Out:
# Index(['S.No.', 'Employee Code', 'Name', 'Designation', 'Grade',
#        'Positin Type', 'SLT/ Non- SLT', 'SMT/ Non-SMT',
#        'Employment Classification - For Gratuity', 'Employment Classification',
#        'Function', 'Sub-Function', 'Constituent', 'HUB/ NSO', 'Location',
#        'Line Manager Employee Code', 'Line Manager', 'Line Manager Email',
#        'Matrix Manager', 'Month of Joining', 'DOJ',
#        'Probation Confirmation Date', 'Probation / Confirmed', 'DOC', 'Gender',
#        'DOB', '(Month of Birth)', 'Age', 'Year of Career Start',
#        'Years in SCBR', 'Total Years of Experience', 'Qualification',
#        'Blood Group', 'Employee Code.1', 'Email_Address', 'Contact Nos', 'PAN',
#        'UAN No./ PF account no.', 'CTC (09/10)', 'CTC (10/11)', 'CTC (11/12)',
#        'CTC\n(2012)', 'CTC\n(2013)', 'CTC\n(2014)', 'CTC\n(2015)',
#        'CTC\n(2016)', 'CTC\n(2017-18)', 'CTC\n(2018-19)', 'CTC\n(2019-20)',
#        'CTC\n(2020-21)', 'CTC\n(2021-22)', 'CTC\n(2022-23)', 'Corrections',
#        'One time Bonus', 'Basic', 'HRA', 'Special allowance', 'Sodexo Pass',
#        'TPT Allowance', 'Medical\nReimb.', 'Gross Salary', 'Movable Assets',
#        'LTA', 'Mediclaim', 'PF', 'Gratuity', 'CTC Monthly', 'CTC Annual',
#        'Check', 'PMS 07-08', 'PMS 08-09', 'PMS 09-10', 'PMS 10-11',
#        'PMS 11-12', 'PMS 12-13', 'PMS 13-14', 'PMS 14-15', 'PMS 15-16',
#        'PMS 16-17', 'PMS 17-18', 'PMS 18-19', 'PMS 2019-20', 'PMS 2020-21',
#        'Aadhar', 'Emergency Contact Nos', 'Father's Name', 'Single / Married',
#        'Date of Marriage', 'Month of Marriage', 'Current Address', 'Address',
#        'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93'],
#       dtype='object')

# %%
Name=input("Enter the Name of the Employee")
data.loc[(data['Name']==Name)]['CTC Annual']
# Out:
# Enter the Name of the Employee Exit
# Series([], Name: CTC Annual, dtype: float64)

# %%
while True:
    Name=input("Enter the Name of the Employee")
    if Name=="Exit":
        break
    CTC=data.loc[(data['Name']==Name)]['CTC Annual']
    print(CTC)
# Out:
# Enter the Name of the Employee Manoj Kumar
# Series([], Name: CTC Annual, dtype: float64)
# Enter the Name of the Employee Sanjay Kumar
# 72    1439488.0
# Name: CTC Annual, dtype: float64
# Enter the Name of the Employee Himanshi Sharma
# 294    468056.0
# Name: CTC Annual, dtype: float64
# Enter the Name of the Employee Exit
