# %%
import pandas as pd

# %%
df=pd.read_csv('../input/insurance-detail-analysis/Insurance Detail Analysis.csv')
df
# Out:
#       S. No.  Unique ID                  Name  Relation                Name.1  \
# 0          1        NaN   Mouchumi Gogoi Bora         1   Mouchumi Gogoi Bora
# 1          2        NaN       AJIMUDDIN AHMED         1       AJIMUDDIN AHMED
# 2          3        NaN         BARISH CHAWRA         1         BARISH CHAWRA
# 3          4        NaN            MANU KURMI         1            MANU KURMI
# 4          5        NaN           PINKI TANTI         1           PINKI TANTI
# ...      ...        ...                   ...       ...                   ...
# 1560    1561        NaN         Kavita Yadav          1         Kavita Yadav
# 1561    1562        NaN  Abdul Mussavir Khan          1  Abdul Mussavir Khan
# 1562    1563        NaN     Rajkumari Panwar          1     Rajkumari Panwar
# 1563    1564        NaN        Bharti Paretha         1         Bharti pareta
# 1564    1565        NaN             Ali Imran         1             Ali Imran
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   S. No.                        1565 non-null   int64
#  1   Unique ID                     0 non-null      float64
#  2   Name                          1565 non-null   object
#  3   Relation                      1565 non-null   int64
#  4   Name.1                        1565 non-null   object
#  5   Relation.1                    1565 non-null   object
#  6   Date of Birth (DD-MMM-YY)     1565 non-null   object
#  7   Gender                        1564 non-null   object
#  8   Date of Joining (DD-MMM-YY)   1560 non-null   object
#  9   Currrent Contract Start Date  0 non-null      float64
#  10  Currrent Contract End Date    0 non-null      float64
#  11  Designation                   1518 non-null   object
# ...

# %%
df['Gender'].value_counts()
# Out:
# Male        749
# Female      710
# Male         45
# male         23
# MALE         13
# Female       11
#  Female       8
#  Male         2
# female        2
# male          1
# Name: Gender, dtype: int64

# %%
df['Gender']=df['Gender'].clip()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:7246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[mask] = np.nan

# %%
df['Gender'].value_counts()
# Out:
# Male        749
# Female      710
# Male         45
# male         23
# MALE         13
# Female       11
#  Female       8
#  Male         2
# female        2
# male          1
# Name: Gender, dtype: int64

# %%
df['Gender'].replace('male','Male',inplace=True)

# %%
df['Gender'].replace(' Male','Male',inplace=True)
df['Gender'].replace('Male ','Male',inplace=True)
df['Gender'].replace('Female ','Female',inplace=True)
df['Gender'].replace(' Female','Female',inplace=True)
df['Gender'].replace('female','Female',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male        817
# Female      723
# MALE         13
#  Female       8
#  Male         2
# male          1
# Name: Gender, dtype: int64

# %%
df['Gender'].replace('MALE','Male',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male        830
# Female      723
#  Female       8
#  Male         2
# male          1
# Name: Gender, dtype: int64

# %%
df['Gender'].replace(' Male','Male',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male        830
# Female      723
#  Female       8
#  Male         2
# male          1
# Name: Gender, dtype: int64

# %%
df['Gender'].replace('male ','Male',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male        831
# Female      723
#  Female       8
#  Male         2
# Name: Gender, dtype: int64

# %%
df['Gender'].replace(' Male','Male',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male        831
# Female      723
#  Female       8
#  Male         2
# Name: Gender, dtype: int64

# %%
df['Gender'].replace(' Male ','Male',inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male        833
# Female      723
#  Female       8
# Name: Gender, dtype: int64

# %%
df['Gender'].replace(' Female ','Female',inplace=True)

# %%
df['Gender'].isna().sum()
# Out:
# 1

# %%
df['Gender'].value_counts()
# Out:
# Male      833
# Female    731
# Name: Gender, dtype: int64

# %%
df
# Out:
#       S. No.  Unique ID                  Name  Relation                Name.1  \
# 0          1        NaN   Mouchumi Gogoi Bora         1   Mouchumi Gogoi Bora
# 1          2        NaN       AJIMUDDIN AHMED         1       AJIMUDDIN AHMED
# 2          3        NaN         BARISH CHAWRA         1         BARISH CHAWRA
# 3          4        NaN            MANU KURMI         1            MANU KURMI
# 4          5        NaN           PINKI TANTI         1           PINKI TANTI
# ...      ...        ...                   ...       ...                   ...
# 1560    1561        NaN         Kavita Yadav          1         Kavita Yadav
# 1561    1562        NaN  Abdul Mussavir Khan          1  Abdul Mussavir Khan
# 1562    1563        NaN     Rajkumari Panwar          1     Rajkumari Panwar
# 1563    1564        NaN        Bharti Paretha         1         Bharti pareta
# 1564    1565        NaN             Ali Imran         1             Ali Imran
#
# ...

# %%
df.drop('Unique ID',axis=1,inplace=True)

# %%
df
# Out:
#       S. No.                  Name  Relation                Name.1 Relation.1  \
# 0          1   Mouchumi Gogoi Bora         1   Mouchumi Gogoi Bora   Employee
# 1          2       AJIMUDDIN AHMED         1       AJIMUDDIN AHMED   Employee
# 2          3         BARISH CHAWRA         1         BARISH CHAWRA   Employee
# 3          4            MANU KURMI         1            MANU KURMI   Employee
# 4          5           PINKI TANTI         1           PINKI TANTI   Employee
# ...      ...                   ...       ...                   ...        ...
# 1560    1561         Kavita Yadav          1         Kavita Yadav    Employee
# 1561    1562  Abdul Mussavir Khan          1  Abdul Mussavir Khan    Employee
# 1562    1563     Rajkumari Panwar          1     Rajkumari Panwar    Employee
# 1563    1564        Bharti Paretha         1         Bharti pareta   Employee
# 1564    1565             Ali Imran         1             Ali Imran   Employee
#
# ...

# %%
unnecessary_columns=['S. No.','Relation','Name.1','Relation.1','Currrent Contract Start Date','Currrent Contract End Date','DBL']

# %%
unnecessary_columns
# Out:
# ['S. No.',
#  'Relation',
#  'Name.1',
#  'Relation.1',
#  'Currrent Contract Start Date',
#  'Currrent Contract End Date',
#  'DBL']

# %%
df=df.drop(unnecessary_columns,axis=1)

# %%
df
# Out:
#                       Name Date of Birth (DD-MMM-YY)  Gender  \
# 0      Mouchumi Gogoi Bora                 01-Jan-86  Female
# 1          AJIMUDDIN AHMED                 30-May-73    Male
# 2            BARISH CHAWRA                 30-Sep-70    Male
# 3               MANU KURMI                 31-Dec-93    Male
# 4              PINKI TANTI                 05-Feb-99  Female
# ...                    ...                       ...     ...
# 1560         Kavita Yadav                   7-May-98  Female
# 1561  Abdul Mussavir Khan                   7-Jul-75    Male
# 1562     Rajkumari Panwar                   6-Feb-77  Female
# 1563        Bharti Paretha                 30-Nov-93  Female
# 1564             Ali Imran                 15-Jan-89    Male
#
#      Date of Joining (DD-MMM-YY)                      Designation  \
# 0                      08-Mar-21   Project - Community Mobiliser
# 1                      08-Mar-21  Project -  Community Mobilizer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         1565 non-null   object
#  1   Date of Birth (DD-MMM-YY)    1565 non-null   object
#  2   Gender                       1564 non-null   object
#  3   Date of Joining (DD-MMM-YY)  1560 non-null   object
#  4   Designation                  1518 non-null   object
#  5   Monthly Consultancy Fees     1091 non-null   object
#  6   Hub                          1565 non-null   object
#  7   Location                     1562 non-null   object
#  8   State                        1565 non-null   object
#  9   Project Name                 1106 non-null   object
#  10  Unnamed: 18                  0 non-null      float64
# dtypes: float64(1), object(10)
# memory usage: 134.6+ KB

# %%
df=df.drop('Project Name ',axis=1)

# %%
df
# Out:
#                       Name Date of Birth (DD-MMM-YY)  Gender  \
# 0      Mouchumi Gogoi Bora                 01-Jan-86  Female
# 1          AJIMUDDIN AHMED                 30-May-73    Male
# 2            BARISH CHAWRA                 30-Sep-70    Male
# 3               MANU KURMI                 31-Dec-93    Male
# 4              PINKI TANTI                 05-Feb-99  Female
# ...                    ...                       ...     ...
# 1560         Kavita Yadav                   7-May-98  Female
# 1561  Abdul Mussavir Khan                   7-Jul-75    Male
# 1562     Rajkumari Panwar                   6-Feb-77  Female
# 1563        Bharti Paretha                 30-Nov-93  Female
# 1564             Ali Imran                 15-Jan-89    Male
#
#      Date of Joining (DD-MMM-YY)                      Designation  \
# 0                      08-Mar-21   Project - Community Mobiliser
# 1                      08-Mar-21  Project -  Community Mobilizer
# ...

# %%
df=df.drop('Unnamed: 18',axis=1)

# %%
df
# Out:
#                       Name Date of Birth (DD-MMM-YY)  Gender  \
# 0      Mouchumi Gogoi Bora                 01-Jan-86  Female
# 1          AJIMUDDIN AHMED                 30-May-73    Male
# 2            BARISH CHAWRA                 30-Sep-70    Male
# 3               MANU KURMI                 31-Dec-93    Male
# 4              PINKI TANTI                 05-Feb-99  Female
# ...                    ...                       ...     ...
# 1560         Kavita Yadav                   7-May-98  Female
# 1561  Abdul Mussavir Khan                   7-Jul-75    Male
# 1562     Rajkumari Panwar                   6-Feb-77  Female
# 1563        Bharti Paretha                 30-Nov-93  Female
# 1564             Ali Imran                 15-Jan-89    Male
#
#      Date of Joining (DD-MMM-YY)                      Designation  \
# 0                      08-Mar-21   Project - Community Mobiliser
# 1                      08-Mar-21  Project -  Community Mobilizer
# ...

# %%
df['State'].value_counts()
# Out:
# Bihar              370
# Maharashtra        169
# Rajasthan          138
# Andhra Pradesh     104
# Delhi              101
# West Bengal         94
# Madhya Pradesh      75
# Jharkhand           62
# Odisha              58
# Assam               52
# Maharastra          50
# Karnataka           47
# HP                  44
# Andhra Pradesh      35
# Odisha              34
# Uttar Pradesh       32
# Telangana           24
# Telangana           20
# Jammu & Kashmir     17
# Maharashtra         12
# Karnataka           10
# TamilNadu            4
# J&K                  4
# J&k                  2
# Tamil Nadu           2
# maharashtra          2
# Andra Pradesh        1
# karnataka            1
# karnataka            1
# Name: State, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Assam', 'Bihar', 'Jharkhand', 'West Bengal', 'Jammu & Kashmir',
#        'Delhi', 'HP ', 'Uttar Pradesh', 'Maharashtra', 'J&k', 'J&K',
#        'TamilNadu', 'Karnataka', 'Karnataka ', 'Telangana ',
#        'Andhra Pradesh ', 'Telangana', 'Andhra Pradesh', 'Odisha',
#        'Odisha ', 'Tamil Nadu', 'Andra Pradesh', 'karnataka ',
#        'karnataka', 'Maharashtra ', 'Maharastra', 'maharashtra',
#        'Madhya Pradesh', 'Rajasthan'], dtype=object)

# %%
df['State'].replace(['Maharashtra','Maharashtra ','Maharastra','maharashtra'],'Maharashtra',inplace=True)

# %%
df['State'].unique()
# Out:
# array(['Assam', 'Bihar', 'Jharkhand', 'West Bengal', 'Jammu & Kashmir',
#        'Delhi', 'HP ', 'Uttar Pradesh', 'Maharashtra', 'J&k', 'J&K',
#        'TamilNadu', 'Karnataka', 'Karnataka ', 'Telangana ',
#        'Andhra Pradesh ', 'Telangana', 'Andhra Pradesh', 'Odisha',
#        'Odisha ', 'Tamil Nadu', 'Andra Pradesh', 'karnataka ',
#        'karnataka', 'Madhya Pradesh', 'Rajasthan'], dtype=object)

# %%
df['State'].replace(['Jammu & Kashmir','J&k',' J&k','J&K'],'Jammu & Kashmir',inplace=True)

# %%
df['State'].unique()
# Out:
# array(['Assam', 'Bihar', 'Jharkhand', 'West Bengal', 'Jammu & Kashmir',
#        'Delhi', 'HP ', 'Uttar Pradesh', 'Maharashtra', 'TamilNadu',
#        'Karnataka', 'Karnataka ', 'Telangana ', 'Andhra Pradesh ',
#        'Telangana', 'Andhra Pradesh', 'Odisha', 'Odisha ', 'Tamil Nadu',
#        'Andra Pradesh', 'karnataka ', 'karnataka', 'Madhya Pradesh',
#        'Rajasthan'], dtype=object)

# %%
df['State'].replace(['Karnataka','karnataka ','karnataka','Karnataka '],'Karnataka',inplace=True)

# %%
df['State'].unique()
# Out:
# array(['Assam', 'Bihar', 'Jharkhand', 'West Bengal', 'Jammu & Kashmir',
#        'Delhi', 'HP ', 'Uttar Pradesh', 'Maharashtra', 'TamilNadu',
#        'Karnataka', 'Telangana ', 'Andhra Pradesh ', 'Telangana',
#        'Andhra Pradesh', 'Odisha', 'Odisha ', 'Tamil Nadu',
#        'Andra Pradesh', 'Madhya Pradesh', 'Rajasthan'], dtype=object)

# %%
df['State'].replace(['Andhra Pradesh ','Andhra Pradesh','Andra Pradesh'],'Andhra Pradesh',inplace=True)
df['State'].replace(['Odisha','Odisha '],'Odisha',inplace=True)

# %%
df['State'].unique()
# Out:
# array(['Assam', 'Bihar', 'Jharkhand', 'West Bengal', 'Jammu & Kashmir',
#        'Delhi', 'HP ', 'Uttar Pradesh', 'Maharashtra', 'TamilNadu',
#        'Karnataka', 'Telangana ', 'Andhra Pradesh', 'Telangana', 'Odisha',
#        'Tamil Nadu', 'Madhya Pradesh', 'Rajasthan'], dtype=object)

# %%
df['State'].replace(['TamilNadu','Tamil Nadu'],'Tamil Nadu',inplace=True)
df['State'].replace(['Telangana','Telangana '],'Telangana',inplace=True)

# %%
df['State'].unique()
# Out:
# array(['Assam', 'Bihar', 'Jharkhand', 'West Bengal', 'Jammu & Kashmir',
#        'Delhi', 'HP ', 'Uttar Pradesh', 'Maharashtra', 'Tamil Nadu',
#        'Karnataka', 'Telangana', 'Andhra Pradesh', 'Odisha',
#        'Madhya Pradesh', 'Rajasthan'], dtype=object)

# %%
df['State'].value_counts()
# Out:
# Bihar              370
# Maharashtra        233
# Andhra Pradesh     140
# Rajasthan          138
# Delhi              101
# West Bengal         94
# Odisha              92
# Madhya Pradesh      75
# Jharkhand           62
# Karnataka           59
# Assam               52
# HP                  44
# Telangana           44
# Uttar Pradesh       32
# Jammu & Kashmir     23
# Tamil Nadu           6
# Name: State, dtype: int64

# %%
df.groupby('Gender')['State'].value_counts()
# Out:
# Gender  State
# Female  Bihar              160
#         Maharashtra        112
#         Delhi               70
#         Andhra Pradesh      63
#         West Bengal         62
#         Rajasthan           47
#         Odisha              37
#         Jharkhand           34
#         Karnataka           33
#         HP                  32
#         Madhya Pradesh      19
#         Assam               17
#         Jammu & Kashmir     15
#         Uttar Pradesh       15
#         Telangana           14
#         Tamil Nadu           1
# Male    Bihar              210
#         Maharashtra        121
#         Rajasthan           91
#         Andhra Pradesh      77
#         Madhya Pradesh      55
#         Odisha              55
#         Assam               35
#         West Bengal         32
#         Delhi               31
#         Telangana           30
#         Jharkhand           28
#         Karnataka           26
#         Uttar Pradesh       17
# ...

# %%
df['Designation'].value_counts()
# Out:
# Tika Mitra                           222
# Volunteer                            108
# Project - Academic Support Fellow     68
# Academic Support Fellow               58
# Spoke Facilitator (Part-time)         48
#                                     ...
# Social Worker                          1
# Psychosocial Counsellor                1
# Projet Assistant                       1
# MRV Driver                             1
# Para medical consultant                1
# Name: Designation, Length: 222, dtype: int64

# %%
df
# Out:
#                       Name Date of Birth (DD-MMM-YY)  Gender  \
# 0      Mouchumi Gogoi Bora                 01-Jan-86  Female
# 1          AJIMUDDIN AHMED                 30-May-73    Male
# 2            BARISH CHAWRA                 30-Sep-70    Male
# 3               MANU KURMI                 31-Dec-93    Male
# 4              PINKI TANTI                 05-Feb-99  Female
# ...                    ...                       ...     ...
# 1560         Kavita Yadav                   7-May-98  Female
# 1561  Abdul Mussavir Khan                   7-Jul-75    Male
# 1562     Rajkumari Panwar                   6-Feb-77  Female
# 1563        Bharti Paretha                 30-Nov-93  Female
# 1564             Ali Imran                 15-Jan-89    Male
#
#      Date of Joining (DD-MMM-YY)                      Designation  \
# 0                      08-Mar-21   Project - Community Mobiliser
# 1                      08-Mar-21  Project -  Community Mobilizer
# ...

# %%
df['Hub'].value_counts()
# Out:
# East     578
# West     445
# South    341
# North    201
# Name: Hub, dtype: int64

# %%
df.groupby('Gender')['Hub'].value_counts()
# Out:
# Gender  Hub
# Female  East     273
#         West     177
#         South    148
#         North    133
# Male    East     305
#         West     267
#         South    193
#         North     68
# Name: Hub, dtype: int64

# %%
Gender_Wise=df.groupby(['Hub','State'])['Gender'].value_counts()

# %%
Gender_Wise
# Out:
# Hub    State            Gender
# East   Assam            Male       35
#                         Female     17
#        Bihar            Male      210
#                         Female    160
#        Jharkhand        Female     34
#                         Male       28
#        West Bengal      Female     62
#                         Male       32
# North  Delhi            Female     70
#                         Male       31
#        HP               Female     32
#                         Male       12
#        Jammu & Kashmir  Female     15
#                         Male        8
#        Maharashtra      Female      1
#        Uttar Pradesh    Male       17
#                         Female     15
# South  Andhra Pradesh   Male       77
#                         Female     63
#        Karnataka        Female     33
#                         Male       26
#        Odisha           Male       55
#                         Female     37
#        Tamil Nadu       Male        5
# ...

# %%
df
# Out:
#                       Name Date of Birth (DD-MMM-YY)  Gender  \
# 0      Mouchumi Gogoi Bora                 01-Jan-86  Female
# 1          AJIMUDDIN AHMED                 30-May-73    Male
# 2            BARISH CHAWRA                 30-Sep-70    Male
# 3               MANU KURMI                 31-Dec-93    Male
# 4              PINKI TANTI                 05-Feb-99  Female
# ...                    ...                       ...     ...
# 1560         Kavita Yadav                   7-May-98  Female
# 1561  Abdul Mussavir Khan                   7-Jul-75    Male
# 1562     Rajkumari Panwar                   6-Feb-77  Female
# 1563        Bharti Paretha                 30-Nov-93  Female
# 1564             Ali Imran                 15-Jan-89    Male
#
#      Date of Joining (DD-MMM-YY)                      Designation  \
# 0                      08-Mar-21   Project - Community Mobiliser
# 1                      08-Mar-21  Project -  Community Mobilizer
# ...

# %%
df=df.drop('Monthly Consultancy Fees',axis=1)

# %%
df
# Out:
#                       Name Date of Birth (DD-MMM-YY)  Gender  \
# 0      Mouchumi Gogoi Bora                 01-Jan-86  Female
# 1          AJIMUDDIN AHMED                 30-May-73    Male
# 2            BARISH CHAWRA                 30-Sep-70    Male
# 3               MANU KURMI                 31-Dec-93    Male
# 4              PINKI TANTI                 05-Feb-99  Female
# ...                    ...                       ...     ...
# 1560         Kavita Yadav                   7-May-98  Female
# 1561  Abdul Mussavir Khan                   7-Jul-75    Male
# 1562     Rajkumari Panwar                   6-Feb-77  Female
# 1563        Bharti Paretha                 30-Nov-93  Female
# 1564             Ali Imran                 15-Jan-89    Male
#
#      Date of Joining (DD-MMM-YY)                      Designation   Hub  \
# 0                      08-Mar-21   Project - Community Mobiliser   East
# 1                      08-Mar-21  Project -  Community Mobilizer   East
# ...

# %%
df.isna().sum()
# Out:
# Name                            0
# Date of Birth (DD-MMM-YY)       0
# Gender                          1
# Date of Joining (DD-MMM-YY)     5
# Designation                    47
# Hub                             0
# Location                        3
# State                           0
# dtype: int64

# %%
df
# Out:
#                       Name Date of Birth (DD-MMM-YY)  Gender  \
# 0      Mouchumi Gogoi Bora                 01-Jan-86  Female
# 1          AJIMUDDIN AHMED                 30-May-73    Male
# 2            BARISH CHAWRA                 30-Sep-70    Male
# 3               MANU KURMI                 31-Dec-93    Male
# 4              PINKI TANTI                 05-Feb-99  Female
# ...                    ...                       ...     ...
# 1560         Kavita Yadav                   7-May-98  Female
# 1561  Abdul Mussavir Khan                   7-Jul-75    Male
# 1562     Rajkumari Panwar                   6-Feb-77  Female
# 1563        Bharti Paretha                 30-Nov-93  Female
# 1564             Ali Imran                 15-Jan-89    Male
#
#      Date of Joining (DD-MMM-YY)                      Designation   Hub  \
# 0                      08-Mar-21   Project - Community Mobiliser   East
# 1                      08-Mar-21  Project -  Community Mobilizer   East
# ...
