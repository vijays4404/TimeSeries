# %%
#import library
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression

# %%
#loading the data
df=pd.read_csv('../input/dissolved-oxygen-prediction-in-river-water/train.csv')
df
# Out:
#       Id  target    O2_1   O2_2  O2_3  O2_4  O2_5  O2_6  O2_7  NH4_1  ...  \
# 0      0   12.58   9.875   9.20   NaN   NaN   NaN   NaN   NaN  0.690  ...
# 1      3    9.37  10.300  10.75   NaN   NaN   NaN   NaN   NaN  0.710  ...
# 2      4    8.35   8.290   7.90   NaN   NaN   NaN   NaN   NaN  2.210  ...
# 3      5    9.57   8.820   6.80   NaN   NaN   NaN   NaN   NaN  0.595  ...
# 4      6    6.00   6.000   6.50   NaN   NaN   NaN   NaN   NaN  0.600  ...
# ..   ...     ...     ...    ...   ...   ...   ...   ...   ...    ...  ...
# 142  208    6.80   7.700   7.50   NaN   NaN   NaN   NaN   NaN  0.380  ...
# 143  211    5.30   6.300   5.65   NaN   NaN   NaN   NaN   NaN  0.370  ...
# 144  212    8.60   8.600  11.00   NaN   NaN   NaN   NaN   NaN  2.400  ...
# 145  213    9.90   9.600  14.10   NaN   NaN   NaN   NaN   NaN  0.310  ...
# 146  214    6.50   6.500   7.70   NaN   NaN   NaN   NaN   NaN  0.190  ...
#
#      NO3_5  NO3_6  NO3_7  BOD5_1  BOD5_2  BOD5_3  BOD5_4  BOD5_5  BOD5_6  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 37 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      147 non-null    int64
#  1   target  147 non-null    float64
#  2   O2_1    145 non-null    float64
#  3   O2_2    145 non-null    float64
#  4   O2_3    32 non-null     float64
#  5   O2_4    31 non-null     float64
#  6   O2_5    33 non-null     float64
#  7   O2_6    37 non-null     float64
#  8   O2_7    37 non-null     float64
#  9   NH4_1   145 non-null    float64
#  10  NH4_2   145 non-null    float64
#  11  NH4_3   32 non-null     float64
#  12  NH4_4   31 non-null     float64
#  13  NH4_5   33 non-null     float64
#  14  NH4_6   37 non-null     float64
#  15  NH4_7   37 non-null     float64
#  16  NO2_1   145 non-null    float64
#  17  NO2_2   145 non-null    float64
#  18  NO2_3   32 non-null     float64
#  19  NO2_4   31 non-null     float64
# ...

# %%
#Preprocessing 
#checking for missing values
null_columns=df.columns[df.isna().sum()>100]

# %%
df=df.drop(null_columns,axis=1)

# %%
df
# Out:
#       Id  target    O2_1   O2_2  NH4_1  NH4_2   NO2_1   NO2_2  NO3_1  NO3_2  \
# 0      0   12.58   9.875   9.20  0.690  1.040  0.0940  0.0990   1.58  1.825
# 1      3    9.37  10.300  10.75  0.710  0.725  0.0585  0.0515   1.21  0.905
# 2      4    8.35   8.290   7.90  2.210  2.210  0.1000  0.1100   1.34  1.250
# 3      5    9.57   8.820   6.80  0.595  0.675  0.0460  0.0535   0.59  0.790
# 4      6    6.00   6.000   6.50  0.600  0.900  0.1800  0.3400   1.36  1.820
# ..   ...     ...     ...    ...    ...    ...     ...     ...    ...    ...
# 142  208    6.80   7.700   7.50  0.380  1.900  0.6200  0.0640   2.80  3.330
# 143  211    5.30   6.300   5.65  0.370  0.500  0.6900  0.9500   4.37  3.160
# 144  212    8.60   8.600  11.00  2.400  3.600  0.1500  0.1400   0.53  3.000
# 145  213    9.90   9.600  14.10  0.310  0.500  0.2100  0.0800   3.10  3.500
# 146  214    6.50   6.500   7.70  0.190  0.260  0.1300  0.0720   0.00  0.000
#
#      BOD5_1  BOD5_2
# 0      4.80   5.850
# ...

# %%
missing_values=df.columns[df.isna().sum()!=0]

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Id        0
# target    0
# O2_1      0
# O2_2      0
# NH4_1     0
# NH4_2     0
# NO2_1     0
# NO2_2     0
# NO3_1     0
# NO3_2     0
# BOD5_1    0
# BOD5_2    0
# dtype: int64

# %%
#spliting the data
df=df.drop('Id',axis=1)
df
# Out:
#      target    O2_1   O2_2  NH4_1  NH4_2   NO2_1   NO2_2  NO3_1  NO3_2  \
# 0     12.58   9.875   9.20  0.690  1.040  0.0940  0.0990   1.58  1.825
# 1      9.37  10.300  10.75  0.710  0.725  0.0585  0.0515   1.21  0.905
# 2      8.35   8.290   7.90  2.210  2.210  0.1000  0.1100   1.34  1.250
# 3      9.57   8.820   6.80  0.595  0.675  0.0460  0.0535   0.59  0.790
# 4      6.00   6.000   6.50  0.600  0.900  0.1800  0.3400   1.36  1.820
# ..      ...     ...    ...    ...    ...     ...     ...    ...    ...
# 142    6.80   7.700   7.50  0.380  1.900  0.6200  0.0640   2.80  3.330
# 143    5.30   6.300   5.65  0.370  0.500  0.6900  0.9500   4.37  3.160
# 144    8.60   8.600  11.00  2.400  3.600  0.1500  0.1400   0.53  3.000
# 145    9.90   9.600  14.10  0.310  0.500  0.2100  0.0800   3.10  3.500
# 146    6.50   6.500   7.70  0.190  0.260  0.1300  0.0720   0.00  0.000
#
#      BOD5_1  BOD5_2
# 0      4.80   5.850
# 1      5.88   6.835
# 2      3.20   2.700
# 3      7.70   7.055
# ...

# %%
#spliting the data
y=df['target']
x=df.drop('target',axis=1)

# %%
#scaling the training data
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#          O2_1      O2_2     NH4_1     NH4_2     NO2_1     NO2_2     NO3_1  \
# 0    0.179369  0.009505  0.219723  0.635946 -0.129370 -0.138744 -0.546590
# 1    0.281515  0.423750  0.262989  0.101929 -0.433342 -0.344849 -0.672310
# 2   -0.201578 -0.337926  3.507976  2.619437 -0.077995 -0.091015 -0.628138
# 3   -0.074195 -0.631906  0.014207  0.017165 -0.540374 -0.336171 -0.882976
# 4   -0.751969 -0.712082  0.025023  0.398605  0.607012  0.906966 -0.621343
# ..        ...       ...       ...       ...       ...       ...       ...
# 139 -0.343382 -0.444827 -0.450908  2.093896  4.374546 -0.290611 -0.132055
# 140 -0.679865 -0.939249 -0.472541 -0.279511  4.973927  3.553785  0.401404
# 141 -0.127071  0.490564  3.919008  4.975891  0.350134  0.039157 -0.903362
# 142  0.113274  1.319053 -0.602341 -0.279511  0.863889 -0.221186 -0.030120
# 143 -0.631796 -0.391377 -0.861940 -0.686381  0.178883 -0.255898 -1.083447
#
#         NO3_2    BOD5_1    BOD5_2
# 0   -0.575052 -0.085090  0.464734
# ...

# %%
#Training the model
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)

# %%
#training the model
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#checking accurary score
model.score(x_test,y_test)
# Out:
# -0.2484472608214794

# %%
model.score(x_train,y_train)
# Out:
# 0.5183088928795486

# %%
y.mean()
# Out:
# 9.145763888888887

# %%
y_new=pd.qcut(y,q=2,labels=[0,1])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y_new,train_size=0.7)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.8181818181818182
