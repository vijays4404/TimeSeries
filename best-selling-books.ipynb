# %% [markdown]
# <a href="https://www.kaggle.com/code/vijays140291/best-selling-books?scriptVersionId=162694562" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df=pd.read_csv('/kaggle/input/best-selling-books/books_data.csv')
#showing the dataset
df=df.drop(df.columns[0],axis=1)
df
# Out:
#                                         Books                   Authors  \
# 0                        A Tale of Two Cities           Charles Dickens
# 1         The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                    And Then There Were None           Agatha Christie
# 4              Dream of the Red Chamber (紅樓夢)                Cao Xueqin
# ..                                        ...                       ...
# 285         The No. 1 Ladies Detective Agency    Alexander McCall Smith
# 286        Der Regenbogenfisch (Rainbow Fish)            Marcus Pfister
# 287                         The Riftwar Cycle          Raymond E. Feist
# 288                        The Thrawn trilogy              Timothy Zahn
# 289                    Wiedźmin (The Witcher)         Andrzej Sapkowski
#
#     Language First_Published  Sales_in_millions
# 0    English            1859              200.0
# ...

# %%
df['Language'].value_counts().plot(kind='bar',color='green')
plt.title('Distribution of Language ')
# Out:
# Text(0.5, 1.0, 'Distribution of Language ')

# %%
df.groupby('Authors')['Sales_in_millions'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='pink')
plt.title('Top 10 authors based on Sales')
# Out:
# Text(0.5, 1.0, 'Top 10 authors based on Sales')

# %%
df.groupby('Books')['Sales_in_millions'].sum().sort_values(ascending=False).head(10).plot(kind='pie',color='y')
plt.title('Top 10 sold books')
# Out:
# Text(0.5, 1.0, 'Top 10 sold books')

# %%
df.groupby('Authors')['Language'].count().sort_values(ascending=False).head(10).plot(kind='bar',color='red')
plt.title('Authors book on number of language')
# Out:
# Text(0.5, 1.0, 'Authors book on number of language')
