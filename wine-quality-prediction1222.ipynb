# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
import tensorflow as tf

# %%
#loading the dataset
df=pd.read_csv('/kaggle/input/white-wine-quality/winequality-white.csv',delimiter=';')
#showing the dataset
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
#checking for null value
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
encode=LabelEncoder()

df['quality']=encode.fit_transform(df['quality'])
{index: label for index,label in enumerate(encode.classes_)}
# Out:
# {0: 3, 1: 4, 2: 5, 3: 6, 4: 7, 5: 8, 6: 9}

# %%
y=df['quality']
x=df.drop('quality',axis=1)
scaler=StandardScaler()

x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns,index=x.index)

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.172097         -0.081770     0.213280        2.821349  -0.035355
# 1         -0.657501          0.215896     0.048001       -0.944765   0.147747
# 2          1.475751          0.017452     0.543838        0.100282   0.193523
# 3          0.409125         -0.478657    -0.117278        0.415768   0.559727
# 4          0.409125         -0.478657    -0.117278        0.415768   0.559727
# ...             ...               ...          ...             ...        ...
# 4893      -0.776015         -0.677101    -0.365197       -0.944765  -0.310008
# 4894      -0.301959          0.414339     0.213280        0.317179   0.056196
# 4895      -0.420473         -0.379435    -1.191592       -1.023637  -0.218457
# 4896      -1.605613          0.116674    -0.282557       -1.043355  -1.088192
# 4897      -1.013043         -0.677101     0.378559       -1.102508  -1.179743
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=123,shuffle=True)

# %%
#Model and training the dataset
x.shape
# Out:
# (4898, 11)

# %%
len(y.unique())
# Out:
# 7

# %%
inputs=tf.keras.Input(shape=(11,))
x=tf.keras.layers.Dense(64,activation='relu')(inputs)
x=tf.keras.layers.Dense(64,activation='relu')(x)
outputs=tf.keras.layers.Dense(7,activation='softmax')(x)
model=tf.keras.Model(inputs=inputs,outputs=outputs)
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
batch_size=32
epochs=100
history=model.fit(x_train,y_train,validation_split=0.2,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4187 - loss: 1.5976 - val_accuracy: 0.5015 - val_loss: 1.2284
# Epoch 2/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5357 - loss: 1.1901 - val_accuracy: 0.5160 - val_loss: 1.1713
# Epoch 3/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5532 - loss: 1.0865 - val_accuracy: 0.5321 - val_loss: 1.1422
# Epoch 4/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5630 - loss: 1.0796 - val_accuracy: 0.5364 - val_loss: 1.1352
# Epoch 5/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5708 - loss: 1.0445 - val_accuracy: 0.5292 - val_loss: 1.1231
# Epoch 6/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5928 - loss: 1.0237 - val_accuracy: 0.5350 - val_loss: 1.1197
# Epoch 7/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5787 - loss: 1.0183 - val_accuracy: 0.5364 - val_loss: 1.1137
# Epoch 8/100
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5566 - loss: 1.2928
# [1.254353404045105, 0.5469387769699097]
