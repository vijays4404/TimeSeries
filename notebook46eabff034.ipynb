# %%
#importing library
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
#loading the dataset
df=pd.read_csv('../input/real-estate-dataset/data.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 506  0.98765   0.0  12.50     0  0.561  6.980  89.0  2.0980    3  320
# 507  0.23456   0.0  12.50     0  0.561  6.980  76.0  2.6540    3  320
# 508  0.44433   0.0  12.50     0  0.561  6.123  98.0  2.9870    3  320
# 509  0.77763   0.0  12.70     0  0.561  6.222  34.0  2.5430    3  329
# 510  0.65432   0.0  12.80     0  0.561  6.760  67.0  2.9870    3  345
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#getting information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     511 non-null    float64
#  1   ZN       511 non-null    float64
#  2   INDUS    511 non-null    float64
#  3   CHAS     511 non-null    int64
#  4   NOX      511 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      511 non-null    float64
#  7   DIS      511 non-null    float64
#  8   RAD      511 non-null    int64
#  9   TAX      511 non-null    int64
#  10  PTRATIO  511 non-null    float64
#  11  B        511 non-null    float64
#  12  LSTAT    511 non-null    float64
#  13  MEDV     511 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 56.0 KB

# %%
#checking for missing values
df['RM'].isna().sum()
# Out:
# 0

# %%
#filling missing values with mean of the column
df['RM']=df['RM'].fillna(df['RM'].mean())

# %%
#splitting the data between x and y
y=df['MEDV']
x=df.drop('MEDV',axis=1)

# %%
#scaling the dataset
scaler=StandardScaler()
x=scaler.fit_transform(x)

# %%
x
# Out:
# array([[-0.41816246,  0.29069132, -1.29606519, ..., -1.4557408 ,
#          0.44385344, -1.01409118],
#        [-0.41570923, -0.48476656, -0.59827044, ..., -0.3184433 ,
#          0.44385344, -0.48005831],
#        [-0.41571156, -0.48476656, -0.59827044, ..., -0.3184433 ,
#          0.39902654, -1.13604581],
#        ...,
#        [-0.36696944, -0.48476656,  0.19774332, ...,  2.0471355 ,
#         -0.14980003,  1.04244887],
#        [-0.32801455, -0.48476656,  0.22706243, ...,  2.0471355 ,
#         -0.14980003,  8.10297964],
#        [-0.34242657, -0.48476656,  0.24172198, ...,  2.0471355 ,
#         -0.39210757,  4.12340775]])

# %%
#train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)

# %%
#getting shape of the model
print(x_train.shape)
print(x_test.shape)
# Out:
# (357, 13)
# (154, 13)

# %%
bootstrap_model=RandomForestRegressor(n_estimators=100,criterion='mse',bootstrap=True)
bootstrap_model.fit(x_train,y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py:392: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# RandomForestRegressor(criterion='mse')

# %%
#printing the result
print(bootstrap_model.score(x_test,y_test))
# Out:
# 0.7873169532840052

# %%
#no bootstrap
no_bootstrap_model=RandomForestRegressor(n_estimators=100,criterion='mse',bootstrap=False)
no_bootstrap_model.fit(x_train,y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_forest.py:392: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# RandomForestRegressor(bootstrap=False, criterion='mse')

# %%
print(no_bootstrap_model.score(x_test,y_test))
# Out:
# 0.6198742902551437

# %%
random=RandomForestRegressor()
random.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print(random.score(x_test,y_test))
# Out:
# 0.7872311151276767
