# %% [markdown]
# <a href="https://colab.research.google.com/github/vijays4404/TimeSeries/blob/main/bitcoin2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import jinja2
from pycaret.regression import *
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading the **Dataset**

# %%
df=pd.read_csv('/content/BTC-USD (1).csv')
#showing the dataset
#setting the date column as index
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %%
df2=df.copy()
#Storing the data in a feature data 
X=df2[['Date','Open','Close']]

# %%
X
# Out:
#                   Date          Open         Close
# 2014-09-17  2014-09-17    465.864014    457.334015
# 2014-09-18  2014-09-18    456.859985    424.440002
# 2014-09-19  2014-09-19    424.102997    394.795990
# 2014-09-20  2014-09-20    394.673004    408.903992
# 2014-09-21  2014-09-21    408.084991    398.821014
# ...                ...           ...           ...
# 2023-01-21  2023-01-21  22677.427734  22777.625000
# 2023-01-22  2023-01-22  22777.986328  22720.416016
# 2023-01-23  2023-01-23  22721.087891  22934.431641
# 2023-01-24  2023-01-24           NaN           NaN
# 2023-01-25  2023-01-25  22664.750000  22651.037109
#
# [3053 rows x 3 columns]

# %%
y=df2['Close']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,shuffle=False)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2442, 3)
# (2442,)
# (611, 3)
# (611,)

# %%
s=setup(data=x_train,target='Close',session_id=123,use_gpu=True)
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target             Close
# 2                            Original Data         (2442, 3)
# 3                           Missing Values             False
# 4                         Numeric Features                 1
# 5                     Categorical Features                 0
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set        (1709, 22)
# 10                    Transformed Test Set         (733, 22)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
compare_models(sort='MSE')
# Out:
#                                     Model        MAE           MSE  \
# huber                     Huber Regressor   226.9773  3.892260e+05
# br                         Bayesian Ridge   228.7453  3.925672e+05
# en                            Elastic Net   230.3140  3.930635e+05
# llar         Lasso Least Angle Regression   236.1648  3.938005e+05
# omp           Orthogonal Matching Pursuit   234.2875  3.951734e+05
# lasso                    Lasso Regression   246.0844  3.977119e+05
# ridge                    Ridge Regression   251.1826  3.992650e+05
# lr                      Linear Regression   251.3828  3.993457e+05
# lar                Least Angle Regression   253.6127  4.002696e+05
# par          Passive Aggressive Regressor   256.7738  4.382039e+05
# knn                 K Neighbors Regressor   254.6951  4.418310e+05
# gbr           Gradient Boosting Regressor   267.8677  4.842181e+05
# rf                Random Forest Regressor   268.5469  4.973328e+05
# ...

# %%
br=create_model('br')
# Out:
#            MAE          MSE      RMSE      R2   RMSLE    MAPE
# Fold
# 0     200.3008  288121.4083  536.7694  0.9958  0.0453  0.0350
# 1     227.4077  333650.1325  577.6246  0.9975  0.0416  0.0290
# 2     257.6114  488305.7535  698.7888  0.9961  0.0432  0.0324
# 3     259.7059  594370.9637  770.9546  0.9951  0.0344  0.0236
# 4     161.3682  191428.7803  437.5257  0.9985  0.0374  0.0279
# 5     262.2190  403389.0465  635.1292  0.9974  0.0325  0.0245
# 6     337.7038  937331.9774  968.1591  0.9949  0.0439  0.0287
# 7     197.1957  230257.3914  479.8514  0.9986  0.0412  0.0293
# 8     187.7429  238120.4900  487.9759  0.9978  0.0339  0.0226
# 9     196.1977  220695.8843  469.7828  0.9984  0.0455  0.0333
# Mean  228.7453  392567.1828  606.2561  0.9970  0.0399  0.0286
# Std    48.8577  219397.1792  158.1792  0.0013  0.0047  0.0039
# INFO:logs:create_model_container: 19
# INFO:logs:master_model_container: 19
# INFO:logs:display_container: 3
# ...

# %%
x_test_predict=x_test.drop('Close',axis=1)

# %%
predict_model(br,data=x_test_predict)
# Out:
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False), probability_threshold=None, encoded_labels=True, drift_report=False, raw_score=False, round=4, verbose=True, ml_usecase=MLUsecase.REGRESSION, display=None, drift_kwargs=None)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor
#                   Date          Open         Label
# 2021-05-25  2021-05-25  38795.781250  38924.401414
# 2021-05-26  2021-05-26  38392.625000  38519.996802
# 2021-05-27  2021-05-27  39316.890625  39447.153575
# 2021-05-28  2021-05-28  38507.082031  38634.813594
# 2021-05-29  2021-05-29  35684.156250  35802.975129
# ...                ...           ...           ...
# ...

# %%
x_test
# Out:
#                   Date          Open         Close
# 2021-05-25  2021-05-25  38795.781250  38402.222656
# 2021-05-26  2021-05-26  38392.625000  39294.199219
# 2021-05-27  2021-05-27  39316.890625  38436.968750
# 2021-05-28  2021-05-28  38507.082031  35697.605469
# 2021-05-29  2021-05-29  35684.156250  34616.066406
# ...                ...           ...           ...
# 2023-01-21  2023-01-21  22677.427734  22777.625000
# 2023-01-22  2023-01-22  22777.986328  22720.416016
# 2023-01-23  2023-01-23  22721.087891  22934.431641
# 2023-01-24  2023-01-24           NaN           NaN
# 2023-01-25  2023-01-25  22664.750000  22651.037109
#
# [611 rows x 3 columns]
