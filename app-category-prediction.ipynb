# %%
#importing library
import pandas as pd
import numpy as np
import plotly.express as ps
import re
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
#loading the data
df=pd.read_csv('../input/google-play-store-apps/googleplaystore.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
#getting information aboput the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # Preprocessing

# %%
unneeded_column=['App','Current Ver','Android Ver']
df=df.drop(unneeded_column,axis=1)

# %%
#checking null values
df.isna().sum()
# Out:
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# dtype: int64

# %%
#checking the shape
df.shape
# Out:
# (10841, 10)

# %%
df['Rating']=df['Rating'].fillna(df['Rating'].mean())

# %%
#getting unique
def get_unique(df,columns):
    return {column: list(df[column].unique()) for column in columns}

#getting categorical column
def get_categorical_column(df):
    return [column for column in df.columns if df.dtypes[column]=='object']

# %%
#calling the function to get categorical data
get_categorical_column(df)
# Out:
# ['Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated']

# %%
get_unique(df,['Installs'])
# Out:
# {'Installs': ['10,000+',
#   '500,000+',
#   '5,000,000+',
#   '50,000,000+',
#   '100,000+',
#   '50,000+',
#   '1,000,000+',
#   '10,000,000+',
#   '5,000+',
#   '100,000,000+',
#   '1,000,000,000+',
#   '1,000+',
#   '500,000,000+',
#   '50+',
#   '100+',
#   '500+',
#   '10+',
#   '1+',
#   '5+',
#   '0+',
#   '0',
#   'Free']}

# %%
df[df['Category']=='1.9']
# Out:
#       Category  Rating Reviews    Size Installs Type     Price Content Rating  \
# 10472      1.9    19.0    3.0M  1,000+     Free    0  Everyone            NaN
#
#                   Genres Last Updated
# 10472  February 11, 2018       1.0.19

# %%
#droping the rows with index values
df=df.drop(10472,axis=0).reset_index(drop=True)

# %%
#changing the column to float
df['Reviews']=df['Reviews'].astype(np.float)

# %%
(df['Size']=='Varies with device').sum()
# Out:
# 1695

# %%
#converting the Size column into float
df['Size']=df['Size'].apply(lambda x: np.NaN if x=='Varies with device' else x)

# %%
df['Size']=df['Size'].apply(lambda x: np.float(x.replace('M',""))*1e6 if type(x)!=float and 'M' in x else x)

# %%
df['Size']=df['Size'].apply(lambda x: np.float(x.replace('k',""))*1e6 if type(x)!=float and 'k' in x else x)

# %%
df['Size'].astype(np.float)
# Out:
# 0        19000000.0
# 1        14000000.0
# 2         8700000.0
# 3        25000000.0
# 4         2800000.0
#             ...
# 10835    53000000.0
# 10836     3600000.0
# 10837     9500000.0
# 10838           NaN
# 10839    19000000.0
# Name: Size, Length: 10840, dtype: float64

# %%
df
# Out:
#                   Category    Rating   Reviews        Size     Installs  Type  \
# 0           ART_AND_DESIGN  4.100000     159.0  19000000.0      10,000+  Free
# 1           ART_AND_DESIGN  3.900000     967.0  14000000.0     500,000+  Free
# 2           ART_AND_DESIGN  4.700000   87510.0   8700000.0   5,000,000+  Free
# 3           ART_AND_DESIGN  4.500000  215644.0  25000000.0  50,000,000+  Free
# 4           ART_AND_DESIGN  4.300000     967.0   2800000.0     100,000+  Free
# ...                    ...       ...       ...         ...          ...   ...
# 10835               FAMILY  4.500000      38.0  53000000.0       5,000+  Free
# 10836               FAMILY  5.000000       4.0   3600000.0         100+  Free
# 10837              MEDICAL  4.193338       3.0   9500000.0       1,000+  Free
# 10838  BOOKS_AND_REFERENCE  4.500000     114.0         NaN       1,000+  Free
# 10839            LIFESTYLE  4.500000  398307.0  19000000.0  10,000,000+  Free
#
#       Price Content Rating                     Genres      Last Updated
# 0         0       Everyone               Art & Design   January 7, 2018
# 1         0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2         0       Everyone               Art & Design    August 1, 2018
# 3         0           Teen               Art & Design      June 8, 2018
# 4         0       Everyone    Art & Design;Creativity     June 20, 2018
# ...     ...            ...                        ...               ...
# 10835     0       Everyone                  Education     July 25, 2017
# 10836     0       Everyone                  Education      July 6, 2018
# 10837     0       Everyone                    Medical  January 20, 2017
# 10838     0     Mature 17+          Books & Reference  January 19, 2015
# 10839     0       Everyone                  Lifestyle     July 25, 2018
#
# [10840 rows x 10 columns]

# %%
df['Installs']=df['Installs'].apply(lambda x:np.float(x.replace(',','').replace('+','')))

# %%
#converting Price column to float
df['Price']=df['Price'].apply(lambda x:np.float(x.replace('$','')))

# %%
get_unique(df,get_categorical_column(df))
# Out:
# {'Category': ['ART_AND_DESIGN',
#   'AUTO_AND_VEHICLES',
#   'BEAUTY',
#   'BOOKS_AND_REFERENCE',
#   'BUSINESS',
#   'COMICS',
#   'COMMUNICATION',
#   'DATING',
#   'EDUCATION',
#   'ENTERTAINMENT',
#   'EVENTS',
#   'FINANCE',
#   'FOOD_AND_DRINK',
#   'HEALTH_AND_FITNESS',
#   'HOUSE_AND_HOME',
#   'LIBRARIES_AND_DEMO',
#   'LIFESTYLE',
#   'GAME',
#   'FAMILY',
#   'MEDICAL',
#   'SOCIAL',
#   'SHOPPING',
#   'PHOTOGRAPHY',
#   'SPORTS',
#   'TRAVEL_AND_LOCAL',
#   'TOOLS',
#   'PERSONALIZATION',
#   'PRODUCTIVITY',
#   'PARENTING',
#   'WEATHER',
#   'VIDEO_PLAYERS',
#   'NEWS_AND_MAGAZINES',
#   'MAPS_AND_NAVIGATION'],
#  'Type': ['Free', 'Paid', nan],
#  'Content Rating': ['Everyone',
#   'Teen',
#   'Everyone 10+',
#   'Mature 17+',
#   'Adults only 18+',
#   'Unrated'],
#  'Genres': ['Art & Design',
#   'Art & Design;Pretend Play',
#   'Art & Design;Creativity',
#   'Art & Design;Action & Adventure',
#   'Auto & Vehicles',
#   'Beauty',
#   'Books & Reference',
#   'Business',
#   'Comics',
#   'Comics;Creativity',
#   'Communication',
#   'Dating',
#   'Education;Education',
#   'Education',
#   'Education;Creativity',
#   'Education;Music & Video',
#   'Education;Action & Adventure',
#   'Education;Pretend Play',
#   'Education;Brain Games',
#   'Entertainment',
#   'Entertainment;Music & Video',
#   'Entertainment;Brain Games',
#   'Entertainment;Creativity',
#   'Events',
#   'Finance',
#   'Food & Drink',
#   'Health & Fitness',
#   'House & Home',
#   'Libraries & Demo',
#   'Lifestyle',
#   'Lifestyle;Pretend Play',
#   'Adventure;Action & Adventure',
#   'Arcade',
#   'Casual',
#   'Card',
#   'Casual;Pretend Play',
#   'Action',
#   'Strategy',
#   'Puzzle',
#   'Sports',
#   'Music',
#   'Word',
#   'Racing',
#   'Casual;Creativity',
#   'Casual;Action & Adventure',
#   'Simulation',
#   'Adventure',
#   'Board',
#   'Trivia',
#   'Role Playing',
#   'Simulation;Education',
#   'Action;Action & Adventure',
#   'Casual;Brain Games',
#   'Simulation;Action & Adventure',
#   'Educational;Creativity',
#   'Puzzle;Brain Games',
#   'Educational;Education',
#   'Card;Brain Games',
#   'Educational;Brain Games',
#   'Educational;Pretend Play',
#   'Entertainment;Education',
#   'Casual;Education',
#   'Music;Music & Video',
#   'Racing;Action & Adventure',
#   'Arcade;Pretend Play',
#   'Role Playing;Action & Adventure',
#   'Simulation;Pretend Play',
#   'Puzzle;Creativity',
#   'Sports;Action & Adventure',
#   'Educational;Action & Adventure',
#   'Arcade;Action & Adventure',
#   'Entertainment;Action & Adventure',
#   'Puzzle;Action & Adventure',
#   'Strategy;Action & Adventure',
#   'Music & Audio;Music & Video',
#   'Health & Fitness;Education',
#   'Adventure;Education',
#   'Board;Brain Games',
#   'Board;Action & Adventure',
#   'Board;Pretend Play',
#   'Casual;Music & Video',
#   'Role Playing;Pretend Play',
#   'Entertainment;Pretend Play',
#   'Video Players & Editors;Creativity',
#   'Card;Action & Adventure',
#   'Medical',
#   'Social',
#   'Shopping',
#   'Photography',
#   'Travel & Local',
#   'Travel & Local;Action & Adventure',
#   'Tools',
#   'Tools;Education',
#   'Personalization',
#   'Productivity',
#   'Parenting',
#   'Parenting;Music & Video',
#   'Parenting;Education',
#   'Parenting;Brain Games',
#   'Weather',
#   'Video Players & Editors',
#   'Video Players & Editors;Music & Video',
#   'News & Magazines',
#   'Maps & Navigation',
#   'Health & Fitness;Action & Adventure',
#   'Educational',
#   'Casino',
#   'Adventure;Brain Games',
#   'Trivia;Education',
#   'Lifestyle;Education',
#   'Books & Reference;Creativity',
#   'Books & Reference;Education',
#   'Puzzle;Education',
#   'Role Playing;Education',
#   'Role Playing;Brain Games',
#   'Strategy;Education',
#   'Racing;Pretend Play',
#   'Communication;Creativity',
#   'Strategy;Creativity'],
#  'Last Updated': ['January 7, 2018',
#   'January 15, 2018',
#   'August 1, 2018',
#   'June 8, 2018',
#   'June 20, 2018',
#   'March 26, 2017',
#   'April 26, 2018',
#   'June 14, 2018',
#   'September 20, 2017',
#   'July 3, 2018',
#   'October 27, 2017',
#   'July 31, 2018',
#   'April 2, 2018',
#   'June 26, 2018',
#   'August 3, 2018',
#   'June 6, 2018',
#   'November 7, 2017',
#   'July 30, 2018',
#   'April 20, 2018',
#   'March 20, 2018',
#   'July 12, 2018',
#   'March 7, 2018',
#   'July 7, 2018',
#   'April 25, 2018',
#   'October 11, 2017',
#   'March 21, 2018',
#   'August 22, 2017',
#   'May 31, 2018',
#   'July 19, 2018',
#   'January 6, 2018',
#   'April 27, 2018',
#   'July 11, 2018',
#   'August 2, 2018',
#   'July 14, 2018',
#   'November 29, 2017',
#   'March 31, 2018',
#   'July 20, 2018',
#   'April 15, 2018',
#   'January 3, 2018',
#   'November 14, 2017',
#   'December 17, 2017',
#   'May 28, 2018',
#   'May 10, 2018',
#   'July 26, 2018',
#   'July 18, 2018',
#   'July 29, 2018',
#   'August 26, 2014',
#   'July 8, 2018',
#   'July 28, 2018',
#   'June 12, 2018',
#   'October 14, 2016',
#   'May 25, 2018',
#   'July 16, 2018',
#   'July 27, 2018',
#   'July 4, 2018',
#   'March 27, 2018',
#   'July 15, 2018',
#   'July 24, 2018',
#   'July 23, 2018',
#   'August 4, 2018',
#   'May 16, 2018',
#   'June 2, 2018',
#   'April 21, 2018',
#   'November 9, 2017',
#   'May 15, 2018',
#   'October 24, 2016',
#   'February 28, 2018',
#   'July 25, 2018',
#   'June 21, 2018',
#   'June 5, 2018',
#   'September 12, 2017',
#   'April 9, 2018',
#   'March 1, 2018',
#   'April 5, 2018',
#   'August 3, 2017',
#   'May 24, 2018',
#   'November 21, 2017',
#   'October 18, 2017',
#   'May 29, 2018',
#   'May 14, 2018',
#   'July 17, 2018',
#   'July 2, 2018',
#   'June 7, 2018',
#   'August 8, 2017',
#   'December 11, 2017',
#   'June 1, 2018',
#   'March 1, 2017',
#   'January 24, 2018',
#   'August 7, 2017',
#   'July 31, 2017',
#   'July 17, 2015',
#   'May 18, 2018',
#   'June 28, 2018',
#   'January 21, 2018',
#   'May 27, 2018',
#   'May 17, 2018',
#   'July 13, 2018',
#   'June 25, 2018',
#   'June 29, 2018',
#   'November 23, 2017',
#   'October 16, 2014',
#   'August 28, 2017',
#   'August 20, 2016',
#   'June 16, 2018',
#   'May 1, 2018',
#   'June 15, 2018',
#   'February 15, 2018',
#   'August 7, 2015',
#   'May 21, 2018',
#   'May 4, 2018',
#   'April 13, 2016',
#   'July 9, 2018',
#   'February 8, 2018',
#   'September 11, 2015',
#   'July 10, 2018',
#   'February 26, 2018',
#   'March 26, 2018',
#   'January 31, 2018',
#   'May 30, 2017',
#   'March 25, 2018',
#   'April 11, 2017',
#   'April 18, 2018',
#   'February 13, 2018',
#   'March 22, 2018',
#   'November 16, 2017',
#   'December 27, 2017',
#   'March 5, 2018',
#   'July 6, 2018',
#   'May 23, 2018',
#   'December 18, 2017',
#   'July 5, 2018',
#   'May 26, 2018',
#   'July 21, 2018',
#   'June 19, 2018',
#   'October 27, 2016',
#   'June 27, 2018',
#   'November 4, 2016',
#   'September 2, 2015',
#   'April 19, 2018',
#   'January 23, 2018',
#   'August 27, 2017',
#   'April 1, 2016',
#   'July 10, 2017',
#   'February 2, 2015',
#   'March 5, 2017',
#   'January 5, 2018',
#   'December 4, 2017',
#   'June 22, 2018',
#   'June 7, 2016',
#   'April 3, 2018',
#   'July 6, 2014',
#   'August 9, 2017',
#   'September 28, 2016',
#   'October 25, 2017',
#   'September 1, 2017',
#   'July 25, 2017',
#   'January 21, 2017',
#   'January 27, 2017',
#   'February 3, 2017',
#   'February 25, 2016',
#   'June 13, 2018',
#   'May 12, 2018',
#   'January 8, 2017',
#   'November 6, 2017',
#   'December 28, 2017',
#   'January 28, 2017',
#   'February 1, 2017',
#   'April 29, 2018',
#   'March 29, 2018',
#   'February 16, 2018',
#   'April 7, 2018',
#   'June 15, 2017',
#   'July 22, 2018',
#   'December 29, 2017',
#   'May 2, 2018',
#   'February 25, 2018',
#   'March 23, 2018',
#   'February 3, 2018',
#   'January 19, 2017',
#   'October 26, 2017',
#   'October 17, 2017',
#   'October 23, 2016',
#   'March 9, 2018',
#   'November 28, 2017',
#   'September 28, 2017',
#   'January 16, 2017',
#   'August 17, 2017',
#   'July 4, 2016',
#   'August 21, 2014',
#   'August 22, 2015',
#   'June 28, 2015',
#   'December 25, 2017',
#   'May 20, 2018',
#   'July 11, 2014',
#   'April 29, 2015',
#   'December 2, 2013',
#   'July 23, 2015',
#   'November 17, 2016',
#   'June 18, 2018',
#   'February 15, 2017',
#   'November 11, 2017',
#   'June 1, 2016',
#   'May 4, 2016',
#   'June 13, 2017',
#   'September 20, 2016',
#   'December 20, 2016',
#   'January 11, 2015',
#   'October 1, 2017',
#   'July 29, 2016',
#   'October 16, 2017',
#   'December 24, 2017',
#   'July 24, 2017',
#   'July 21, 2017',
#   'January 20, 2018',
#   'April 28, 2016',
#   'July 16, 2015',
#   'September 14, 2016',
#   'February 14, 2018',
#   'February 7, 2018',
#   'June 11, 2018',
#   'April 12, 2018',
#   'January 19, 2018',
#   'December 14, 2017',
#   'June 30, 2018',
#   'July 7, 2017',
#   'September 15, 2015',
#   'September 22, 2015',
#   'November 27, 2017',
#   'June 23, 2018',
#   'November 8, 2016',
#   'October 14, 2017',
#   'April 27, 2017',
#   'December 15, 2017',
#   'May 30, 2018',
#   'May 3, 2018',
#   'May 8, 2018',
#   'June 9, 2018',
#   'June 7, 2017',
#   'March 13, 2018',
#   'May 11, 2018',
#   'May 9, 2018',
#   'February 22, 2018',
#   'October 12, 2016',
#   'March 28, 2018',
#   'January 25, 2018',
#   'June 10, 2018',
#   'June 24, 2018',
#   'February 17, 2017',
#   'April 10, 2018',
#   'June 3, 2018',
#   'May 22, 2018',
#   'August 12, 2017',
#   'January 10, 2017',
#   'October 16, 2016',
#   'December 22, 2015',
#   'February 9, 2017',
#   'July 28, 2016',
#   'January 17, 2018',
#   'June 19, 2012',
#   'August 5, 2018',
#   'March 30, 2018',
#   'February 10, 2018',
#   'July 17, 2017',
#   'August 27, 2016',
#   'August 23, 2017',
#   'January 29, 2018',
#   'July 23, 2014',
#   'July 16, 2017',
#   'March 11, 2017',
#   'February 22, 2017',
#   'February 18, 2018',
#   'March 2, 2016',
#   'September 19, 2017',
#   'August 21, 2017',
#   'March 13, 2015',
#   'April 7, 2015',
#   'March 17, 2015',
#   'May 30, 2015',
#   'March 6, 2015',
#   'March 12, 2015',
#   'March 11, 2015',
#   'August 30, 2017',
#   'April 23, 2018',
#   'October 15, 2015',
#   'February 20, 2018',
#   'January 16, 2018',
#   'March 6, 2013',
#   'January 17, 2012',
#   'June 10, 2017',
#   'September 27, 2017',
#   'March 8, 2018',
#   'January 2, 2017',
#   'March 14, 2016',
#   'November 5, 2017',
#   'February 23, 2018',
#   'November 7, 2016',
#   'June 29, 2011',
#   'September 21, 2015',
#   'February 12, 2013',
#   'January 9, 2018',
#   'July 1, 2018',
#   'December 20, 2017',
#   'November 3, 2016',
#   'June 30, 2016',
#   'September 24, 2015',
#   'December 17, 2016',
#   'February 21, 2018',
#   'September 27, 2016',
#   'January 11, 2018',
#   'May 7, 2018',
#   'August 2, 2017',
#   'August 29, 2017',
#   'June 5, 2017',
#   'January 26, 2017',
#   'April 30, 2014',
#   'June 18, 2017',
#   'October 12, 2017',
#   'August 28, 2015',
#   'July 18, 2017',
#   'February 27, 2016',
#   'June 23, 2017',
#   'March 8, 2017',
#   'April 17, 2018',
#   'March 6, 2018',
#   'April 13, 2018',
#   'April 11, 2018',
#   'December 22, 2017',
#   'February 27, 2018',
#   'December 21, 2017',
#   'October 19, 2015',
#   'November 30, 2017',
#   'April 12, 2017',
#   'June 28, 2017',
#   'March 14, 2017',
#   'October 15, 2017',
#   'July 28, 2017',
#   'March 16, 2018',
#   'August 6, 2018',
#   'June 4, 2018',
#   'November 22, 2016',
#   'February 1, 2018',
#   'June 29, 2017',
#   'July 14, 2017',
#   'October 6, 2017',
#   'July 12, 2017',
#   'August 31, 2017',
#   'November 22, 2017',
#   'March 7, 2017',
#   'October 4, 2017',
#   'July 22, 2016',
#   'May 18, 2017',
#   'February 2, 2018',
#   'February 18, 2016',
#   'March 15, 2017',
#   'March 5, 2016',
#   'February 2, 2016',
#   'January 13, 2017',
#   'July 13, 2017',
#   'December 1, 2015',
#   'June 17, 2015',
#   'March 23, 2017',
#   'July 3, 2017',
#   'September 8, 2016',
#   'September 3, 2015',
#   'November 14, 2014',
#   'December 13, 2017',
#   'August 2, 2016',
#   'February 9, 2016',
#   'August 12, 2015',
#   'August 24, 2015',
#   'June 16, 2016',
#   'May 22, 2013',
#   'August 4, 2017',
#   'October 28, 2016',
#   'December 9, 2014',
#   'December 9, 2017',
#   'December 30, 2016',
#   'February 5, 2016',
#   'April 14, 2016',
#   'February 11, 2016',
#   'November 30, 2014',
#   'April 6, 2018',
#   'October 3, 2016',
#   'June 17, 2017',
#   'September 21, 2017',
#   'November 15, 2017',
#   'August 7, 2014',
#   'December 6, 2017',
#   'December 3, 2014',
#   'April 18, 2017',
#   'January 24, 2016',
#   'October 22, 2014',
#   'November 22, 2012',
#   'August 18, 2015',
#   'December 16, 2015',
#   'November 5, 2013',
#   'May 26, 2015',
#   'March 14, 2018',
#   'August 5, 2017',
#   'August 11, 2017',
#   'December 8, 2016',
#   'August 3, 2015',
#   'October 5, 2017',
#   'June 11, 2016',
#   'August 2, 2014',
#   'September 14, 2017',
#   'September 6, 2014',
#   'January 2, 2018',
#   'July 26, 2013',
#   'March 2, 2017',
#   'October 3, 2017',
#   'May 6, 2015',
#   'January 14, 2018',
#   'May 9, 2017',
#   'October 2, 2017',
#   'October 10, 2017',
#   'October 13, 2016',
#   'October 17, 2016',
#   'December 8, 2017',
#   'March 24, 2018',
#   'October 22, 2013',
#   'September 6, 2016',
#   'December 23, 2017',
#   'April 4, 2018',
#   'June 1, 2017',
#   'April 24, 2018',
#   'September 26, 2017',
#   'January 18, 2015',
#   'March 14, 2015',
#   'May 10, 2015',
#   'February 25, 2017',
#   'April 16, 2018',
#   'September 12, 2016',
#   'November 20, 2017',
#   'October 25, 2016',
#   'January 20, 2015',
#   'January 30, 2018',
#   'June 8, 2016',
#   'February 29, 2016',
#   'December 5, 2017',
#   'July 25, 2015',
#   'December 1, 2017',
#   'March 5, 2015',
#   'January 22, 2018',
#   'February 6, 2018',
#   'July 29, 2015',
#   'November 8, 2017',
#   'November 2, 2016',
#   'January 25, 2016',
#   'July 29, 2017',
#   'August 11, 2015',
#   'November 10, 2017',
#   'March 25, 2016',
#   'May 5, 2018',
#   'February 10, 2015',
#   'March 3, 2017',
#   'February 11, 2015',
#   'October 19, 2016',
#   'October 17, 2015',
#   'April 6, 2017',
#   'February 11, 2018',
#   'November 6, 2014',
#   'March 21, 2017',
#   'July 18, 2016',
#   'September 8, 2017',
#   'January 7, 2016',
#   'March 16, 2017',
#   'August 23, 2016',
#   'December 5, 2016',
#   'December 6, 2016',
#   'July 14, 2016',
#   'March 21, 2016',
#   'July 5, 2016',
#   'November 13, 2017',
#   'July 14, 2015',
#   'August 10, 2016',
#   'November 21, 2014',
#   'January 17, 2016',
#   'July 27, 2016',
#   'November 13, 2014',
#   'March 27, 2017',
#   'January 3, 2017',
#   'May 12, 2017',
#   'April 22, 2014',
#   'July 11, 2017',
#   'November 18, 2017',
#   'August 10, 2015',
#   'September 17, 2017',
#   'February 5, 2018',
#   'April 28, 2017',
#   'August 7, 2018',
#   'September 5, 2016',
#   'May 12, 2016',
#   'March 18, 2018',
#   'April 25, 2014',
#   'December 2, 2017',
#   'September 25, 2017',
#   'March 9, 2017',
#   'December 10, 2017',
#   'January 22, 2017',
#   'November 1, 2016',
#   'August 24, 2016',
#   'October 20, 2016',
#   'December 7, 2016',
#   'May 11, 2016',
#   'April 4, 2014',
#   'January 7, 2015',
#   'March 17, 2018',
#   'December 24, 2016',
#   'May 1, 2014',
#   'November 28, 2016',
#   'June 24, 2014',
#   'October 29, 2017',
#   'May 27, 2016',
#   'October 9, 2017',
#   'August 10, 2017',
#   'April 22, 2016',
#   'April 14, 2017',
#   'March 15, 2018',
#   'August 7, 2016',
#   'December 11, 2016',
#   'December 19, 2015',
#   'October 30, 2017',
#   'September 30, 2013',
#   'November 12, 2017',
#   'October 18, 2016',
#   'December 25, 2016',
#   'May 19, 2018',
#   'April 25, 2016',
#   'August 8, 2016',
#   'January 8, 2018',
#   'November 1, 2017',
#   'January 9, 2017',
#   'August 18, 2016',
#   'December 30, 2017',
#   'January 7, 2017',
#   'April 1, 2018',
#   'March 19, 2018',
#   'October 31, 2017',
#   'November 19, 2017',
#   'December 3, 2015',
#   'February 13, 2015',
#   'February 3, 2015',
#   'June 3, 2016',
#   'October 30, 2014',
#   'January 13, 2018',
#   'March 11, 2016',
#   'May 25, 2017',
#   'August 9, 2016',
#   'February 19, 2018',
#   'November 2, 2017',
#   'December 4, 2016',
#   'August 26, 2016',
#   'January 5, 2017',
#   'April 22, 2018',
#   'June 16, 2017',
#   'May 13, 2018',
#   'September 13, 2017',
#   'September 12, 2014',
#   'November 24, 2017',
#   'June 11, 2015',
#   'April 12, 2016',
#   'May 19, 2017',
#   'May 4, 2015',
#   'August 19, 2017',
#   'December 22, 2016',
#   'October 22, 2016',
#   'August 16, 2015',
#   'September 2, 2017',
#   'March 31, 2016',
#   'June 20, 2017',
#   'August 26, 2017',
#   'July 31, 2014',
#   'May 13, 2017',
#   'June 24, 2017',
#   'December 16, 2017',
#   'April 4, 2016',
#   'September 26, 2015',
#   'January 20, 2016',
#   'June 3, 2017',
#   'August 31, 2016',
#   'September 22, 2017',
#   'May 16, 2014',
#   'March 2, 2018',
#   'January 18, 2018',
#   'November 26, 2015',
#   'May 3, 2017',
#   'October 23, 2017',
#   'October 6, 2016',
#   'February 21, 2017',
#   'August 5, 2015',
#   'December 26, 2017',
#   'July 24, 2016',
#   'October 7, 2016',
#   'December 15, 2016',
#   'January 28, 2014',
#   'April 21, 2017',
#   'March 15, 2016',
#   'July 19, 2016',
#   'July 12, 2016',
#   'December 7, 2017',
#   'January 25, 2017',
#   'September 8, 2013',
#   'September 1, 2015',
#   'September 26, 2016',
#   'April 10, 2013',
#   'October 21, 2017',
#   'December 7, 2015',
#   'January 1, 2016',
#   'September 30, 2017',
#   'April 7, 2016',
#   'November 3, 2017',
#   'February 8, 2017',
#   'December 14, 2015',
#   'May 19, 2015',
#   'November 20, 2015',
#   'February 4, 2018',
#   'September 10, 2017',
#   'January 4, 2016',
#   'December 19, 2017',
#   'January 1, 2018',
#   'September 7, 2017',
#   'November 16, 2016',
#   'October 22, 2017',
#   'April 30, 2018',
#   'October 20, 2017',
#   'December 12, 2017',
#   'March 12, 2018',
#   'May 14, 2014',
#   'October 17, 2014',
#   'July 23, 2016',
#   'June 17, 2018',
#   'May 8, 2017',
#   'January 13, 2014',
#   'May 1, 2016',
#   'April 21, 2016',
#   'January 11, 2017',
#   'November 17, 2017',
#   'August 22, 2013',
#   'April 4, 2017',
#   'June 6, 2016',
#   'September 7, 2015',
#   'April 2, 2016',
#   'February 12, 2017',
#   'December 4, 2015',
#   'March 11, 2018',
#   'March 20, 2017',
#   'July 9, 2017',
#   'January 12, 2018',
#   'May 17, 2017',
#   'July 15, 2016',
#   'February 9, 2018',
#   'March 28, 2017',
#   'May 25, 2015',
#   'July 1, 2015',
#   'March 6, 2017',
#   'February 15, 2016',
#   'December 26, 2014',
#   'May 31, 2017',
#   'August 20, 2017',
#   'December 3, 2011',
#   'April 25, 2017',
#   'September 14, 2015',
#   'May 6, 2018',
#   'April 14, 2018',
#   'February 12, 2018',
#   'March 16, 2015',
#   'August 4, 2016',
#   'April 1, 2017',
#   'May 16, 2017',
#   'March 4, 2017',
#   'July 12, 2014',
#   'March 16, 2016',
#   'December 3, 2017',
#   'December 8, 2015',
#   'May 15, 2017',
#   'February 21, 2014',
#   'May 14, 2017',
#   'September 24, 2017',
#   'September 16, 2014',
#   'June 20, 2016',
#   'April 28, 2018',
#   'May 29, 2017',
#   'August 7, 2013',
#   'February 27, 2017',
#   'July 8, 2016',
#   'January 31, 2017',
#   'September 19, 2012',
#   'February 12, 2016',
#   'August 14, 2017',
#   'November 15, 2014',
#   'April 3, 2017',
#   'October 24, 2017',
#   'April 20, 2016',
#   'August 25, 2015',
#   'February 24, 2016',
#   'August 19, 2014',
#   'November 8, 2012',
#   'September 27, 2013',
#   'September 29, 2016',
#   'May 14, 2013',
#   'April 8, 2018',
#   'June 25, 2017',
#   'March 3, 2018',
#   'September 11, 2017',
#   'February 5, 2014',
#   'October 7, 2017',
#   'January 28, 2018',
#   'February 24, 2018',
#   'January 23, 2017',
#   'September 20, 2014',
#   'June 22, 2017',
#   'November 19, 2016',
#   'September 3, 2017',
#   'January 4, 2017',
#   'April 11, 2014',
#   'February 26, 2014',
#   'December 31, 2017',
#   'January 25, 2015',
#   'October 19, 2017',
#   'March 4, 2018',
#   'November 13, 2015',
#   'July 28, 2015',
#   'August 1, 2017',
#   'November 5, 2014',
#   'July 31, 2016',
#   'June 30, 2017',
#   'April 8, 2016',
#   'March 13, 2017',
#   'July 10, 2014',
#   'July 10, 2015',
#   'November 3, 2015',
#   'June 15, 2016',
#   'June 21, 2016',
#   'February 23, 2017',
#   'February 2, 2017',
#   'September 15, 2016',
#   'December 31, 2016',
#   'October 8, 2012',
#   'July 9, 2014',
#   'November 23, 2016',
#   'July 19, 2017',
#   'December 11, 2015',
#   'July 30, 2016',
#   'January 8, 2015',
#   'June 2, 2017',
#   'November 27, 2015',
#   'June 8, 2017',
#   'October 28, 2014',
#   'July 30, 2015',
#   'December 28, 2015',
#   'July 28, 2014',
#   'August 20, 2015',
#   'December 17, 2013',
#   'May 7, 2016',
#   'May 3, 2014',
#   'September 25, 2013',
#   'December 21, 2016',
#   'July 26, 2016',
#   'September 17, 2015',
#   'April 25, 2013',
#   'May 26, 2014',
#   'August 9, 2014',
#   'November 20, 2013',
#   'September 30, 2016',
#   'March 23, 2016',
#   'January 19, 2014',
#   'December 31, 2015',
#   'January 4, 2018',
#   'December 13, 2013',
#   'November 12, 2013',
#   'June 27, 2017',
#   'December 31, 2014',
#   'January 24, 2014',
#   'January 1, 2015',
#   'October 9, 2015',
#   'December 10, 2015',
#   'June 15, 2015',
#   'August 1, 2013',
#   'October 26, 2016',
#   'December 9, 2016',
#   'January 25, 2013',
#   'December 19, 2013',
#   'June 29, 2016',
#   'November 28, 2012',
#   'May 1, 2017',
#   'May 2, 2017',
#   'November 20, 2014',
#   'March 20, 2015',
#   'March 31, 2017',
#   'June 9, 2017',
#   'May 23, 2017',
#   'May 5, 2017',
#   'June 26, 2017',
#   'April 30, 2017',
#   'October 28, 2017',
#   'May 12, 2011',
#   'June 21, 2017',
#   'October 1, 2013',
#   'May 11, 2017',
#   'January 10, 2018',
#   'April 22, 2017',
#   'May 26, 2017',
#   'November 4, 2017',
#   'June 3, 2015',
#   'September 25, 2015',
#   'February 18, 2013',
#   'March 7, 2016',
#   'May 4, 2017',
#   'January 27, 2018',
#   'June 13, 2016',
#   'March 24, 2017',
#   'June 4, 2013',
#   'August 15, 2016',
#   'September 29, 2017',
#   'March 17, 2017',
#   'September 7, 2016',
#   'November 11, 2016',
#   'February 26, 2017',
#   'April 26, 2015',
#   'March 1, 2016',
#   'March 10, 2018',
#   'May 2, 2015',
#   'September 11, 2013',
#   'February 15, 2015',
#   'March 25, 2017',
#   'June 24, 2015',
#   'February 17, 2018',
#   'October 8, 2016',
#   'April 5, 2017',
#   'March 10, 2016',
#   'April 10, 2015',
#   'October 21, 2016',
#   'May 10, 2017',
#   'February 23, 2016',
#   'March 11, 2014',
#   'December 23, 2016',
#   'June 2, 2016',
#   'March 8, 2016',
#   'May 14, 2015',
#   'August 30, 2015',
#   'August 12, 2014',
#   'March 22, 2016',
#   'November 1, 2013',
#   'August 14, 2016',
#   'August 31, 2013',
#   'July 19, 2015',
#   'July 30, 2017',
#   'January 19, 2016',
#   'November 4, 2015',
#   'August 15, 2017',
#   'October 14, 2015',
#   'June 22, 2016',
#   'February 23, 2014',
#   'September 22, 2011',
#   'January 23, 2016',
#   'May 24, 2017',
#   'September 30, 2014',
#   'December 26, 2016',
#   'July 18, 2013',
#   'December 3, 2016',
#   'July 26, 2015',
#   'April 2, 2015',
#   'June 6, 2017',
#   'November 26, 2017',
#   'December 2, 2014',
#   'May 22, 2017',
#   'January 26, 2018',
#   'May 14, 2016',
#   'July 1, 2016',
#   'September 18, 2017',
#   'September 5, 2017',
#   'August 3, 2016',
#   'April 8, 2017',
#   'September 22, 2016',
#   'March 6, 2014',
#   'September 19, 2013',
#   'August 4, 2014',
#   'May 17, 2016',
#   'July 6, 2017',
#   'September 15, 2017',
#   'September 4, 2013',
#   'June 6, 2015',
#   'July 15, 2015',
#   'October 20, 2015',
#   'February 14, 2017',
#   'February 8, 2016',
#   'October 12, 2015',
#   'October 26, 2015',
#   'July 4, 2017',
#   'November 11, 2015',
#   'October 2, 2014',
#   'July 8, 2017',
#   'December 19, 2016',
#   'November 26, 2012',
#   'November 25, 2017',
#   'February 23, 2015',
#   'August 18, 2017',
#   'December 1, 2016',
#   'February 16, 2017',
#   'August 31, 2015',
#   'July 6, 2015',
#   'October 27, 2015',
#   'June 13, 2014',
#   'July 21, 2016',
#   'December 21, 2015',
#   'August 5, 2016',
#   'October 5, 2016',
#   'April 11, 2016',
#   'April 17, 2014',
#   'February 18, 2017',
#   'August 13, 2015',
#   'March 28, 2016',
#   'December 14, 2016',
#   'November 16, 2015',
#   'July 2, 2017',
#   'August 13, 2016',
#   'May 30, 2016',
#   'September 23, 2015',
#   'September 29, 2015',
#   'November 2, 2015',
#   'April 15, 2016',
#   'February 18, 2015',
#   'August 15, 2013',
#   'October 5, 2015',
#   'October 8, 2015',
#   'February 19, 2016',
#   'April 9, 2012',
#   'January 19, 2015',
#   'January 12, 2016',
#   'May 16, 2016',
#   'April 29, 2017',
#   'December 18, 2015',
#   'October 7, 2015',
#   'September 13, 2015',
#   'July 22, 2017',
#   'December 12, 2016',
#   'November 10, 2016',
#   'May 26, 2016',
#   'January 27, 2016',
#   'January 16, 2016',
#   'January 29, 2016',
#   'November 12, 2014',
#   'September 4, 2017',
#   'June 18, 2015',
#   'March 31, 2015',
#   'June 9, 2015',
#   'February 22, 2016',
#   'October 4, 2015',
#   'August 28, 2016',
#   'July 26, 2017',
#   'April 23, 2017',
#   'November 9, 2015',
#   'June 14, 2015',
#   'May 25, 2016',
#   'July 5, 2017',
#   'November 12, 2015',
#   'June 12, 2017',
#   'March 19, 2017',
#   'October 2, 2015',
#   'July 11, 2015',
#   'June 14, 2016',
#   'September 23, 2017',
#   'March 29, 2017',
#   'December 15, 2015',
#   'November 9, 2016',
#   'September 17, 2016',
#   'October 30, 2015',
#   'November 10, 2014',
#   'October 13, 2015',
#   'November 19, 2015',
#   'August 16, 2016',
#   'November 29, 2016',
#   'February 6, 2017',
#   'November 26, 2014',
#   'October 3, 2015',
#   'September 22, 2014',
#   'May 8, 2015',
#   'August 12, 2016',
#   'December 2, 2016',
#   'July 7, 2016',
#   'March 30, 2015',
#   'April 20, 2015',
#   'January 12, 2017',
#   'March 20, 2014',
#   'January 6, 2017',
#   'May 23, 2016',
#   'August 8, 2015',
#   'June 10, 2015',
#   'July 16, 2016',
#   'March 22, 2015',
#   'February 3, 2016',
#   'February 7, 2016',
#   'April 14, 2015',
#   'July 18, 2014',
#   'June 5, 2014',
#   'July 1, 2013',
#   'February 20, 2017',
#   'May 6, 2013',
#   'April 24, 2016',
#   ...]}

# %%
df[df['Type'].isna()]
# Out:
#      Category    Rating  Reviews  Size  Installs Type  Price Content Rating  \
# 9148   FAMILY  4.193338      0.0   NaN       0.0  NaN    0.0   Everyone 10+
#
#         Genres   Last Updated
# 9148  Strategy  June 28, 2018

# %%
df=df.drop(9148,axis=0).reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# Category             0
# Rating               0
# Reviews              0
# Size              1694
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# dtype: int64

# %%
#filling na value with mean in rating column
df['Rating']=df['Rating'].fillna(df['Rating'].mean())

# %%
#filling na values with mean in size column
df['Size']=df['Size'].fillna(df['Size'].mean())

# %%
#checking na values
df.isna().sum()
# Out:
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# dtype: int64

# %%
df
# Out:
#                   Category    Rating   Reviews          Size    Installs  \
# 0           ART_AND_DESIGN  4.100000     159.0  1.900000e+07     10000.0
# 1           ART_AND_DESIGN  3.900000     967.0  1.400000e+07    500000.0
# 2           ART_AND_DESIGN  4.700000   87510.0  8.700000e+06   5000000.0
# 3           ART_AND_DESIGN  4.500000  215644.0  2.500000e+07  50000000.0
# 4           ART_AND_DESIGN  4.300000     967.0  2.800000e+06    100000.0
# ...                    ...       ...       ...           ...         ...
# 10834               FAMILY  4.500000      38.0  5.300000e+07      5000.0
# 10835               FAMILY  5.000000       4.0  3.600000e+06       100.0
# 10836              MEDICAL  4.193338       3.0  9.500000e+06      1000.0
# 10837  BOOKS_AND_REFERENCE  4.500000     114.0  3.703544e+07      1000.0
# 10838            LIFESTYLE  4.500000  398307.0  1.900000e+07  10000000.0
#
#        Type  Price Content Rating                     Genres      Last Updated
# 0      Free    0.0       Everyone               Art & Design   January 7, 2018
# 1      Free    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2      Free    0.0       Everyone               Art & Design    August 1, 2018
# 3      Free    0.0           Teen               Art & Design      June 8, 2018
# 4      Free    0.0       Everyone    Art & Design;Creativity     June 20, 2018
# ...     ...    ...            ...                        ...               ...
# 10834  Free    0.0       Everyone                  Education     July 25, 2017
# 10835  Free    0.0       Everyone                  Education      July 6, 2018
# 10836  Free    0.0       Everyone                    Medical  January 20, 2017
# 10837  Free    0.0     Mature 17+          Books & Reference  January 19, 2015
# 10838  Free    0.0       Everyone                  Lifestyle     July 25, 2018
#
# [10839 rows x 10 columns]

# %%
#extracing month
df['Month']=df['Last Updated'].apply(lambda x: re.search('^[^\s]+',x).group(0))

# %%
#extracting year
df['Year']=df['Last Updated'].apply(lambda x: re.search('[^\s]+$',x).group(0))

# %%
df=df.drop('Last Updated',axis=1)

# %%
#changing data type to float
df['Year']=df['Year'].apply(lambda x: np.float(x))

# %%
df
# Out:
#                   Category    Rating   Reviews          Size    Installs  \
# 0           ART_AND_DESIGN  4.100000     159.0  1.900000e+07     10000.0
# 1           ART_AND_DESIGN  3.900000     967.0  1.400000e+07    500000.0
# 2           ART_AND_DESIGN  4.700000   87510.0  8.700000e+06   5000000.0
# 3           ART_AND_DESIGN  4.500000  215644.0  2.500000e+07  50000000.0
# 4           ART_AND_DESIGN  4.300000     967.0  2.800000e+06    100000.0
# ...                    ...       ...       ...           ...         ...
# 10834               FAMILY  4.500000      38.0  5.300000e+07      5000.0
# 10835               FAMILY  5.000000       4.0  3.600000e+06       100.0
# 10836              MEDICAL  4.193338       3.0  9.500000e+06      1000.0
# 10837  BOOKS_AND_REFERENCE  4.500000     114.0  3.703544e+07      1000.0
# 10838            LIFESTYLE  4.500000  398307.0  1.900000e+07  10000000.0
#
#        Type  Price Content Rating                     Genres    Month    Year
# 0      Free    0.0       Everyone               Art & Design  January  2018.0
# 1      Free    0.0       Everyone  Art & Design;Pretend Play  January  2018.0
# 2      Free    0.0       Everyone               Art & Design   August  2018.0
# 3      Free    0.0           Teen               Art & Design     June  2018.0
# 4      Free    0.0       Everyone    Art & Design;Creativity     June  2018.0
# ...     ...    ...            ...                        ...      ...     ...
# 10834  Free    0.0       Everyone                  Education     July  2017.0
# 10835  Free    0.0       Everyone                  Education     July  2018.0
# 10836  Free    0.0       Everyone                    Medical  January  2017.0
# 10837  Free    0.0     Mature 17+          Books & Reference  January  2015.0
# 10838  Free    0.0       Everyone                  Lifestyle     July  2018.0
#
# [10839 rows x 11 columns]

# %%
#labeling category column with label encoder
label_encoder=LabelEncoder()
df['Category']=label_encoder.fit_transform(df['Category'])

# %%
category_mapping={index:label for index,label in enumerate(label_encoder.classes_)}
category_mapping
# Out:
# {0: 'ART_AND_DESIGN',
#  1: 'AUTO_AND_VEHICLES',
#  2: 'BEAUTY',
#  3: 'BOOKS_AND_REFERENCE',
#  4: 'BUSINESS',
#  5: 'COMICS',
#  6: 'COMMUNICATION',
#  7: 'DATING',
#  8: 'EDUCATION',
#  9: 'ENTERTAINMENT',
#  10: 'EVENTS',
#  11: 'FAMILY',
#  12: 'FINANCE',
#  13: 'FOOD_AND_DRINK',
#  14: 'GAME',
#  15: 'HEALTH_AND_FITNESS',
#  16: 'HOUSE_AND_HOME',
#  17: 'LIBRARIES_AND_DEMO',
#  18: 'LIFESTYLE',
#  19: 'MAPS_AND_NAVIGATION',
#  20: 'MEDICAL',
#  21: 'NEWS_AND_MAGAZINES',
#  22: 'PARENTING',
#  23: 'PERSONALIZATION',
#  24: 'PHOTOGRAPHY',
#  25: 'PRODUCTIVITY',
#  26: 'SHOPPING',
#  27: 'SOCIAL',
#  28: 'SPORTS',
#  29: 'TOOLS',
#  30: 'TRAVEL_AND_LOCAL',
#  31: 'VIDEO_PLAYERS',
#  32: 'WEATHER'}

# %%
def binary_encoder(df,column,positive_value):
    df=df.copy()
    df[column]=df[column].apply(lambda x:1 if x==positive_value else 0)
    return df

def ordinal_encode(df,column,ordering):
    df=df.copy()
    df[column]=df[column].apply(lambda x:ordering.index(x))
    return df

# %%
 install_ordering=[  '0',
  '0+',
  '1+',
  '5+',
  '10+',
  '50+',
  '100+',
  '500+',
  '1,000+',
  '5,000+',
    '10,000+',
       '50,000+',
       '100,000+',
       '500,000+',
      '1,000,000+',
       '5,000,000+',
  '10,000,000+',
  '50,000,000+',
  '100,000,000+',
       
  '500,000,000+',
       '1,000,000,000+'
  ]

# %%
print(install_ordering)
# Out:
# ['0', '0+', '1+', '5+', '10+', '50+', '100+', '500+', '1,000+', '5,000+', '10,000+', '50,000+', '100,000+', '500,000+', '1,000,000+', '5,000,000+', '10,000,000+', '50,000,000+', '100,000,000+', '500,000,000+', '1,000,000,000+']

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
rating_order=['Everyone','Everyone 10+','Teen','Mature 17+',
             'Adults only 18+','Unrated']

# %%
df['Month'].unique()
# Out:
# array(['January', 'August', 'June', 'March', 'April', 'September', 'July',
#        'October', 'November', 'May', 'December', 'February'], dtype=object)

# %%
month_ordering=['January','February','March','April',
               'May','June','July','August','September',
                'October','November','December']

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df=binary_encode(df,'Type','Paid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_33/1795218964.py in <module>
# ----> 1 df=binary_encode(df,'Type','Paid')
#
# NameError: name 'binary_encode' is not defined

# %%
df=ordinal_encode(df,'Month',month_ordering)

# %%
df=ordinal_encode(df,'Content Rating',rating_order)

# %%
df['Installs'].unique()

# %%
df

# %%
df=df.drop('Genres',axis=1)

# %%
df

# %%
y=df['Category']
x=df.drop('Category',axis=1)

# %%
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)

# %%
x.shape

# %%
inputs=tf.keras.Input(shape=(9,))
x=tf.keras.layers.Dense(64,activation='relu')(inputs)
x=tf.keras.layers.Dense(64,activation='relu')(x)
outputs=tf.keras.layers.Dense(33,activation='softmax')(x)
model=tf.keras.Model(inputs=inputs,outputs=outputs)
model.compile(
optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
batch_size=64
epochs=100
history=model.fit(
x_train,
y_train,
validation_split=0.2,
batch_size=batch_size,
epochs=epochs,
callbacks=[tf.keras.callbacks.ReduceLROnPlateau()],
verbose=0)

# %%
model.evaluate(x_test,y_test)
# Out:
# 102/102 [==============================] - 0s 2ms/step - loss: 2.7009 - accuracy: 0.2494
# [2.70094633102417, 0.24938499927520752]
