# %% [markdown]
# <a href="https://www.kaggle.com/code/vijays140291/songs-popularity?scriptVersionId=122190691" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv('/kaggle/input/spotify-dataset-19212020-600k-tracks/tracks.csv')
#loading the dataset
df
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %% [markdown]
# # Checking for Null Values IN the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %% [markdown]
# # Checking for Null Values

# %%
df.isna().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %% [markdown]
# * Therer are 71 null value in the name column

# %% [markdown]
# # Getting the Numerical Columns

# %%
quantitative_columns=[column for column in df.columns if df[column].dtypes!='object']
df=df[quantitative_columns]

# %% [markdown]
# # Getting the Histogram for quantitative Columns

# %%
for column in quantitative_columns:
    plt.hist(df[column])
    plt.show()

# %%
for column in quantitative_columns:
    plt.title(column)
    plt.boxplot(df[column])
    plt.show()

# %% [markdown]
# # Ploting Time Signature

# %%
df['time_signature'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='time_signature'>

# %% [markdown]
# # Preprocessing the dataset

# %%
def preprocess_inputs(df):
    df=df.copy()
    y=df['popularity']
    x=df.drop('popularity',axis=1)
    #train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)
    scaler=StandardScaler()
    scaler.fit(x_train)
    x_train=pd.DataFrame(scaler.transform(x_train),columns=x_train.columns)
    x_test=pd.DataFrame(scaler.transform(x_test),columns=x_test.columns)
    return x_train,x_test,y_train,y_test

# %%
x_train,x_test,y_train,y_test=preprocess_inputs(df)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (410670, 14)
# (176002, 14)
# (410670,)
# (176002,)

# %% [markdown]
# # Training the Model

# %%
model=LinearRegression()
model.fit(x_train,y_train)
print(model.score(x_test,y_test))
# Out:
# 0.22497824988963955

# %% [markdown]
# # Random Forest Model

# %%
rf_model=RandomForestRegressor()
rf_model.fit(x_train,y_train)
rf_model.score(x_test,y_test)
# Out:
# 0.38205257901544976

# %%
df['popularity'].unique()
# Out:
# array([  6,   0,   1,   4,  41,  38,  30,  28,  27,  26,  25,  23,  22,
#         20,  18,  17,  16,  15,  14,  11,  10,   8,   9,   5,   7,   2,
#         39,  33,  32,  24,  21,  19,  13,  12,   3,  51,  48,  40,  34,
#         29,  47,  43,  37,  35,  31,  55,  50,  36,  42,  65,  53,  45,
#         49,  46,  44,  52,  56,  54,  61,  62,  57,  69,  58,  68,  60,
#         64,  63,  67,  66,  59,  74,  71,  77,  70,  79,  75,  73,  72,
#         80,  78,  76,  82,  83,  84,  81,  86,  85,  87,  90,  88,  89,
#         94,  92,  97,  96,  95,  93,  91, 100,  99,  98])

# %% [markdown]
# # Plotting graph for categorical Columns

# %%
df
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 0                6       126903         0         0.645  0.4450    0
# 1                0        98200         0         0.695  0.2630    0
# 2                0       181640         0         0.434  0.1770    1
# 3                0       176907         0         0.321  0.0946    7
# 4                0       163080         0         0.402  0.1580    3
# ...            ...          ...       ...           ...     ...  ...
# 586667          50       258267         0         0.560  0.5180    0
# 586668          72       153293         0         0.765  0.6630    0
# 586669          70       187601         0         0.535  0.3140    7
# 586670          58       142003         0         0.696  0.6150   10
# 586671          38       214360         0         0.686  0.7230    6
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
[column for column in df.select_dtypes('object')]
# Out:
# ['id', 'name', 'artists', 'id_artists', 'release_date']
