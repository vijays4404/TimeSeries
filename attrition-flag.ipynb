# %%
#importing library
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
#loading the dataset
df=pd.read_csv('../input/credit-card-customers/BankChurners.csv')
#showing the data
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
#getting information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
#preprocessing 
def preprocess_inputs(df):
    df=df.copy()
    return df

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
df['Education_Level']
# Out:
# 0        High School
# 1           Graduate
# 2           Graduate
# 3        High School
# 4         Uneducated
#             ...
# 10122       Graduate
# 10123        Unknown
# 10124    High School
# 10125       Graduate
# 10126       Graduate
# Name: Education_Level, Length: 10127, dtype: object

# %%
df['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
df['Card_Category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
#converting card category to numerical
card={'Blue':1,'Gold':2,'Silver':3,'Platinum':4}
df['Card_Category']=df['Card_Category'].replace(card)

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category  Card_Category  \
# ...

# %%
df['Card_Category'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category  Card_Category  \
# ...

# %%
df.isna().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
df=df.drop(df.columns[22],axis=1)

# %%
df=df.drop(df.columns[21],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  int64
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  int64
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  int64
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  float64
# ...

# %%
{column:len(df[column].unique()) for column in df.columns}
# Out:
# {'CLIENTNUM': 10127,
#  'Attrition_Flag': 2,
#  'Customer_Age': 45,
#  'Gender': 2,
#  'Dependent_count': 6,
#  'Education_Level': 7,
#  'Marital_Status': 4,
#  'Income_Category': 6,
#  'Card_Category': 4,
#  'Months_on_book': 44,
#  'Total_Relationship_Count': 6,
#  'Months_Inactive_12_mon': 7,
#  'Contacts_Count_12_mon': 7,
#  'Credit_Limit': 6205,
#  'Total_Revolving_Bal': 1974,
#  'Avg_Open_To_Buy': 6813,
#  'Total_Amt_Chng_Q4_Q1': 1158,
#  'Total_Trans_Amt': 5033,
#  'Total_Trans_Ct': 126,
#  'Total_Ct_Chng_Q4_Q1': 830,
#  'Avg_Utilization_Ratio': 964}

# %%
df['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
Attrition_Flag={'Existing Customer':1,'Attrited Customer':2}
df['Attrition_Flag']=df['Attrition_Flag'].replace(Attrition_Flag)

# %%
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383               1            45      M                3
# 1      818770008               1            49      F                5
# 2      713982108               1            51      M                3
# 3      769911858               1            40      F                4
# 4      709106358               1            40      M                3
# ...          ...             ...           ...    ...              ...
# 10122  772366833               1            50      M                2
# 10123  710638233               2            41      M                2
# 10124  716506083               2            44      F                1
# 10125  717406983               2            30      M                2
# 10126  714337233               2            43      F                2
#
#       Education_Level Marital_Status Income_Category  Card_Category  \
# ...

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
Gender={'M':1,'F':0}
df['Gender']=df['Gender'].replace(Gender)

# %%
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383               1            45       1                3
# 1      818770008               1            49       0                5
# 2      713982108               1            51       1                3
# 3      769911858               1            40       0                4
# 4      709106358               1            40       1                3
# ...          ...             ...           ...     ...              ...
# 10122  772366833               1            50       1                2
# 10123  710638233               2            41       1                2
# 10124  716506083               2            44       0                1
# 10125  717406983               2            30       1                2
# 10126  714337233               2            43       0                2
#
#       Education_Level Marital_Status Income_Category  Card_Category  \
# ...

# %%
df['Marital_Status'].unique()
# Out:
# array(['Married', 'Single', 'Unknown', 'Divorced'], dtype=object)

# %%
df['Marital_Status']
# Out:
# 0         Married
# 1          Single
# 2         Married
# 3         Unknown
# 4         Married
#            ...
# 10122      Single
# 10123    Divorced
# 10124     Married
# 10125     Unknown
# 10126     Married
# Name: Marital_Status, Length: 10127, dtype: object

# %%
df['Marital_Status'].unique()
# Out:
# array(['Married', 'Single', 'Unknown', 'Divorced'], dtype=object)

# %%
Marital_Status={'Married':1,'Single':0,'Unknown':2,'Divorced':3}
df['Marital_Status']=df['Marital_Status'].replace(Marital_Status)

# %%
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383               1            45       1                3
# 1      818770008               1            49       0                5
# 2      713982108               1            51       1                3
# 3      769911858               1            40       0                4
# 4      709106358               1            40       1                3
# ...          ...             ...           ...     ...              ...
# 10122  772366833               1            50       1                2
# 10123  710638233               2            41       1                2
# 10124  716506083               2            44       0                1
# 10125  717406983               2            30       1                2
# 10126  714337233               2            43       0                2
#
#       Education_Level  Marital_Status Income_Category  Card_Category  \
# ...

# %%
def onehot_encode(df,column):
    df=df.copy()
    dummies=pd.get_dummies(df[column],prefix=column)
    df=pd.concat([df,dummies],axis=1)
    df=df.drop(column,axis=1)
    return df

# %%
df=onehot_encode(df,'Education_Level')

# %%
df=onehot_encode(df,'Income_Category')

# %%
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383               1            45       1                3
# 1      818770008               1            49       0                5
# 2      713982108               1            51       1                3
# 3      769911858               1            40       0                4
# 4      709106358               1            40       1                3
# ...          ...             ...           ...     ...              ...
# 10122  772366833               1            50       1                2
# 10123  710638233               2            41       1                2
# 10124  716506083               2            44       0                1
# 10125  717406983               2            30       1                2
# 10126  714337233               2            43       0                2
#
#        Marital_Status  Card_Category  Months_on_book  \
# ...

# %%
#Splitting into x and y
y=df['Attrition_Flag']
x=df.drop('Attrition_Flag',axis=1)

# %%
#train_Test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=1)

# %%
#scaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=pd.DataFrame(scaler.fit_transform(x_train),columns=x_train.columns,index=x_train.index)
x_test=pd.DataFrame(scaler.fit_transform(x_test),columns=x_test.columns,index=x_test.index)

# %%
# Out:
#       CLIENTNUM  Customer_Age    Gender  Dependent_count  Marital_Status  \
# 6498  -0.731016     -0.418874 -0.950233        -0.272812        0.221958
# 9013  -0.568613     -1.046688 -0.950233        -1.050557        1.403270
# 2053  -0.792719     -0.921125  1.052373        -0.272812        0.221958
# 3211  -0.597224     -0.293311  1.052373         1.282678        0.221958
# 5559  -0.810280     -1.046688 -0.950233        -0.272812        0.221958
# ...         ...           ...       ...              ...             ...
# 9826  -0.687741     -0.418874 -0.950233         0.504933       -0.959355
# 9200  -0.643811      1.715696  1.052373        -1.050557        0.221958
# 5221  -0.615084     -1.046688  1.052373        -1.828302       -0.959355
# 1224  -0.836609      1.339007 -0.950233         0.504933        0.221958
# 6122  -0.667411      0.711193 -0.950233        -1.050557        1.403270
#
#       Card_Category  Months_on_book  Total_Relationship_Count  \
# ...

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9068772622573215

# %%
model1=DecisionTreeClassifier()
model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model1.score(x_test,y_test)
# Out:
# 0.9404409345179335
